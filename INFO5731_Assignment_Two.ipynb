# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargav1237874/grandhe_INFO5731_spring2021/blob/main/INFO5731_Assignment_Two.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Two**
#
# In this assignment, you will try to gather text data from open data source via web scraping or API. After that you need to clean the text data and syntactic analysis of the data.

# %% [markdown]
# # **Question 1**

# %% [markdown]
# (40 points). Write a python program to collect text data from **either of the following sources** and save the data into a **csv file**:
#
# (1) Collect all the customer reviews of the product [2019 Dell labtop](https://www.amazon.com/Dell-Inspiron-5000-5570-Laptop/dp/B07N49F51N/ref=sr_1_11?crid=1IJ7UWF2F4GHH&keywords=dell%2Bxps%2B15&qid=1580173569&sprefix=dell%2Caps%2C181&sr=8-11&th=1) on amazon.
#
# (2) Collect the top 100 User Reviews of the film [Joker](https://www.imdb.com/title/tt7286456/reviews?ref_=tt_urv) from IMDB.
#
# (3) Collect the abstracts of the top 100 research papers by using the query [natural language processing](https://citeseerx.ist.psu.edu/search?q=natural+language+processing&submit.x=0&submit.y=0&sort=rlv&t=doc) from CiteSeerX.
#
# (4) Collect the top 100 tweets by using hashtag ["#CovidVaccine"](https://twitter.com/hashtag/CovidVaccine) from Twitter.

# %%
import json
import tweepy
import csv
import pandas as pd
twitter_cred = dict()


twitter_cred['CONSUMER_KEY'] = 'u7L1lnR7HN85dn1qnTFO1cegb'
twitter_cred['CONSUMER_SECRET'] = 'QN1JrEmit2To46ZcwWAT4aI5QGWZXWRDDUPnMCWV5M66SFc8wT'
twitter_cred['ACCESS_KEY'] = '1144377060036620294-BSEicX3zH7hIhksbNZV9mrWFwa07cO'
twitter_cred['ACCESS_SECRET'] = 'gxWMOodDq1nQAjix9mHEOUSAtgE7XH5ctHInm0XRslJce'
created=[]
tweetext=[]

with open('twitter_credentials.json', 'w') as secret_info:
  json.dump(twitter_cred, secret_info, indent=4, sort_keys=True)

with open('twitter_credentials.json') as cred_data:
  info = json.load(cred_data)
  consumer_key = info['CONSUMER_KEY']
  consumer_secret = info['CONSUMER_SECRET']
  access_key = info['ACCESS_KEY']
  access_secret = info['ACCESS_SECRET']

  auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
  api = tweepy.API(auth)

  extracted_tweets = int(input('No. of tweets to extraxt- '))
  tag = input('Please enter the topic. ')

  for i in tweepy.Cursor(api.search, q='#' + tag, rpp=100).items(extracted_tweets):

    created.append(i.created_at)
    tweetext.append(i.text)

covid_tweets=pd.DataFrame({'tweets':tweetext,'created':created})
covid_tweets.to_csv('corona_vaccine.csv')
print(covid_tweets[:100])
# Out:
# No. of tweets to extraxt- 100
# Please enter the topic. covidvaccine
#                                                tweets             created
# 0   RT @mid_day: Officials say state, #BMC are sti... 2021-02-27 04:02:45
# 1   FDA panel endorses Johnson &amp; Johnson #covi... 2021-02-27 04:00:32
# 2   How do you know which one is right for you? #C... 2021-02-27 04:00:00
# 3   Thank you @WCSedu nurses and the staff that ma... 2021-02-27 03:59:22
# 4   @mentionitaII Me, regarding the two doses of t... 2021-02-27 03:58:17
# ..                                                ...                 ...
# 95  RT @Shakesnews_: Vaccinations at Oakland’s Col... 2021-02-27 02:37:22
# 96  And you think people gonna take this from fuck... 2021-02-27 02:37:07
# 97  RT @WRES_team: With thanks to @NHSEnglandLDN f... 2021-02-27 02:33:46
# 98  Dissing Dallas? County Judge Clay Jenkins says... 2021-02-27 02:33:37
# 99  RT @SteveAdubato: #ThisWknd on #ThinkTankSA @S... 2021-02-27 02:31:52
#
# [100 rows x 2 columns]

# %% [markdown]
# # **Question 2**

# %% [markdown]
# (30 points). Write a python program to **clean the text data** you collected above and save the data in a new column in the csv file. The data cleaning steps include:
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the [stopwords list](https://gist.github.com/sebleier/554280).
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
# Write your code here

import nltk
nltk.download('punkt')
from nltk.corpus import stopwords
nltk.download('stopwords')

#noise removal
covid_tweets['Noise removal']=covid_tweets['tweets'].str.replace('[^\w\s]','')
covid_tweets['Noise removal']=covid_tweets['tweets'].apply(lambda x: " ".join(x for x in x.split()))

#Numbers removal
covid_tweets['Numbers removal']=covid_tweets['Noise removal'].str.replace('[0-9]','')

#Stop words removal
stop = stopwords.words('english')
covid_tweets['Stopwords removal']=covid_tweets['Numbers removal'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

#Lowercase
covid_tweets['lowercase']=covid_tweets['Stopwords removal'].apply(lambda x: " ".join(x.lower() for x in x.split()))

#Stemming
from nltk.stem import PorterStemmer
st = PorterStemmer()
covid_tweets['stemming']=covid_tweets['lowercase'].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))


#Lemmatization
from textblob import Word
nltk.download('wordnet')
covid_tweets['after Lemmatization']=covid_tweets['stemming'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))

covid_tweets
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#                                                tweets  ...                                after Lemmatization
# 0   RT @mid_day: Officials say state, #BMC are sti...  ...  rt @mid_day: offici say state, #bmc still awai...
# 1   FDA panel endorses Johnson &amp; Johnson #covi...  ...  fda panel endors johnson &amp; johnson #covidv...
# 2   How do you know which one is right for you? #C...  ...  how know one right you? #covidvaccin https://t...
# 3   Thank you @WCSedu nurses and the staff that ma...  ...  thank @wcsedu nurs staff made vaccin distribut...
# 4   @mentionitaII Me, regarding the two doses of t...  ...  @mentionitaii me, regard two dose @pfizer vacc...
# ..                                                ...  ...                                                ...
# 95  RT @Shakesnews_: Vaccinations at Oakland’s Col...  ...  rt @shakesnews_: vaccin oakland’ coliseum. eff...
# 96  And you think people gonna take this from fuck...  ...  and think peopl gonna take fuck india? @justin...
# 97  RT @WRES_team: With thanks to @NHSEnglandLDN f...  ...  rt @wres_team: with thank @nhsenglandldn devel...
# 98  Dissing Dallas? County Judge Clay Jenkins says...  ...  dis dallas? counti judg clay jenkin say state ...
# 99  RT @SteveAdubato: #ThisWknd on #ThinkTankSA @S...  ...  rt @steveadubato: #thiswknd #thinktanksa @sher...
#
# [100 rows x 8 columns]

# %% [markdown]
# # **Question 3**

# %% [markdown]
# (30 points). Write a python program to conduct **syntax and structure analysis** of the clean text you just saved above. The syntax and structure analysis includes:
#
# (1) Parts of Speech (POS) Tagging: Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) Constituency Parsing and Dependency Parsing: print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) Named Entity Recognition: Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
# Write your code here

# !pip install benepar
# Out:
# Collecting benepar
#   Downloading https://files.pythonhosted.org/packages/9e/17/c398a35d0f303a534de8ec6949aa2ee68cc6bdbf0930685d92719b97aa1e/benepar-0.2.0.tar.gz
# Requirement already satisfied: nltk>=3.2 in /usr/local/lib/python3.7/dist-packages (from benepar) (3.2.5)
# Requirement already satisfied: spacy>=2.0.9 in /usr/local/lib/python3.7/dist-packages (from benepar) (2.2.4)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from benepar) (1.7.1+cu101)
# Collecting torch-struct>=0.5
#   Downloading https://files.pythonhosted.org/packages/b2/8c/775b7e141f11d509d59d0d2d801337ff3ad0203bc1a40335ea83e1161ba7/torch_struct-0.5-py3-none-any.whl
# Collecting tokenizers>=0.9.4
#   Downloading https://files.pythonhosted.org/packages/71/23/2ddc317b2121117bf34dd00f5b0de194158f2a44ee2bf5e47c7166878a97/tokenizers-0.10.1-cp37-cp37m-manylinux2010_x86_64.whl (3.2MB)
#      |████████████████████████████████| 3.2MB 8.1MB/s
# Collecting transformers[tokenizers,torch]>=4.2.2
#   Downloading https://files.pythonhosted.org/packages/f9/54/5ca07ec9569d2f232f3166de5457b63943882f7950ddfcc887732fc7fb23/transformers-4.3.3-py3-none-any.whl (1.9MB)
#      |████████████████████████████████| 1.9MB 39.1MB/s
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from benepar) (3.12.4)
# Collecting sentencepiece>=0.1.91
#   Downloading https://files.pythonhosted.org/packages/f5/99/e0808cb947ba10f575839c43e8fafc9cc44e4a7a2c8f79c60db48220a577/sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 35.5MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk>=3.2->benepar) (1.15.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.0.9->benepar) (0.4.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.0.9->benepar) (1.19.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.0.9->benepar) (3.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.0.9->benepar) (0.8.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.0.9->benepar) (2.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.0.9->benepar) (1.0.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.0.9->benepar) (1.1.3)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.0.9->benepar) (1.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.0.9->benepar) (2.23.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.0.9->benepar) (4.41.1)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.0.9->benepar) (7.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.0.9->benepar) (53.0.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.0.9->benepar) (1.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->benepar) (3.7.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers[tokenizers,torch]>=4.2.2->benepar) (3.0.12)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers[tokenizers,torch]>=4.2.2->benepar) (3.7.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers[tokenizers,torch]>=4.2.2->benepar) (20.9)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 50.8MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers[tokenizers,torch]>=4.2.2->benepar) (2019.12.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (2020.12.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers[tokenizers,torch]>=4.2.2->benepar) (3.4.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers[tokenizers,torch]>=4.2.2->benepar) (2.4.7)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers[tokenizers,torch]>=4.2.2->benepar) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers[tokenizers,torch]>=4.2.2->benepar) (1.0.1)
# Building wheels for collected packages: benepar, sacremoses
#   Building wheel for benepar (setup.py) ... done
#   Created wheel for benepar: filename=benepar-0.2.0-cp37-none-any.whl size=37647 sha256=9cb2f44776442dde4200e92dc3be726845a986ff33e81b0445a508bd15904f0e
#   Stored in directory: /root/.cache/pip/wheels/dd/90/28/513063023646df7774be9401c440a5f13b48bdbab15a67fc42
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp37-none-any.whl size=893262 sha256=e1b11e486833eb841a82f1a6f904ac728263f4e615437bb586d69564ea3ca43c
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built benepar sacremoses
# Installing collected packages: torch-struct, tokenizers, sacremoses, transformers, sentencepiece, benepar
# Successfully installed benepar-0.2.0 sacremoses-0.0.43 sentencepiece-0.1.95 tokenizers-0.10.1 torch-struct-0.5 transformers-4.3.3

# %%
# !pip install tensorflow==1.14
# Out:
# Collecting tensorflow==1.14
#   Downloading https://files.pythonhosted.org/packages/f4/28/96efba1a516cdacc2e2d6d081f699c001d414cc8ca3250e6d59ae657eb2b/tensorflow-1.14.0-cp37-cp37m-manylinux1_x86_64.whl (109.3MB)
#      |████████████████████████████████| 109.3MB 50kB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.1.0)
# Collecting keras-applications>=1.0.6
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 6.2MB/s
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.36.2)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.10.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.2.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.8.1)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.19.5)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (3.12.4)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.12.1)
# Collecting tensorboard<1.15.0,>=1.14.0
#   Downloading https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.2MB 48.7MB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.32.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.15.0)
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0
#   Downloading https://files.pythonhosted.org/packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488kB)
#      |████████████████████████████████| 491kB 34.2MB/s
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.1.2)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.3.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.6->tensorflow==1.14) (2.10.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.6.1->tensorflow==1.14) (53.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (1.0.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (3.7.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (3.7.4.3)
# Installing collected packages: keras-applications, tensorboard, tensorflow-estimator, tensorflow
#   Found existing installation: tensorboard 2.4.1
#     Uninstalling tensorboard-2.4.1:
#       Successfully uninstalled tensorboard-2.4.1
#   Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
#       Successfully uninstalled tensorflow-estimator-2.4.0
#   Found existing installation: tensorflow 2.4.1
#     Uninstalling tensorflow-2.4.1:
#       Successfully uninstalled tensorflow-2.4.1
# Successfully installed keras-applications-1.0.8 tensorboard-1.14.0 tensorflow-1.14.0 tensorflow-estimator-1.14.0

# %%
nltk.download('averaged_perceptron_tagger')
nltk.download('universal_tagset')
parts_of_speech=[]
count=[]
n=0


for i in covid_tweets['tweets']:
  token=nltk.word_tokenize(i)
  partsofspeech.append(nltk.pos_tag(token,tagset='universal'))
  count.append(nltk.FreqDist(tag for (word, tag) in partsofspeech[0]))
  
  print(partsofspeech[n])
  print(count[n])
  n=n+1

print(count)



# Dependcy parsing
import spacy
from spacy import displacy
k=spacy.load('en_core_web_sm')


for j in covid_tweets['tweets']:

  displacy.render(k(j),jupyter=True)



# constituent parsing
# %tensorflow_version 1.x
import benepar
import nltk
benepar.download('benepar_en3')


from benepar.spacy_plugin import BeneparComponent
m= spacy.load('en')
m.add_pipe(BeneparComponent('benepar_en3'))


for i in covid_tweets['tweets']:
  k= m(i)
  p = list(k.sents)[0]
  print(p._.parse_string)




#3-3 Name Entity Recognition
import spacy
from spacy import displacy
k=[]
l = spacy.load('en_core_web_sm')


for i in covid_tweets['tweets']:
  for j in l(i).ents:
    k.append((j.label_,j.text))
    print(j.label_,j.text)

nltk.FreqDist(label for (label, text) in k)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [('RT', 'NOUN'), ('@', 'NOUN'), ('nilikm', 'NOUN'), (':', '.'), ('So', 'ADV'), ('@', 'ADP'), ('GeneralHillier', 'NOUN'), ('says', 'VERB'), ('he', 'PRON'), ('can', 'VERB'), ('’', 'VERB'), ('t', 'ADJ'), ('imagine', 'VERB'), ('how', 'ADV'), ('this', 'DET'), ('rollout', 'NOUN'), ('could', 'VERB'), ('be', 'VERB'), ('better', 'ADJ'), ('in', 'ADP'), ('Ontario', 'NOUN'), ('.', '.'), ('Family', 'NOUN'), ('docs', 'VERB'), ('say', 'VERB'), ('it', 'PRON'), ("'s", 'VERB'), ('chaos', 'NOUN'), ('.', '.'), ('Whom', 'NOUN'), ('do', 'VERB'), ('you', 'PRON'), ('b…', 'VERB')]
# <FreqDist with 8 samples and 33 outcomes>
# [('I', 'PRON'), ('’', 'VERB'), ('m', 'ADV'), ('saving', 'VERB'), ('this', 'DET'), ('.', '.'), ('I', 'PRON'), ('hope', 'VERB'), ('to', 'PRT'), ('write', 'VERB'), ('the', 'DET'), ('exact', 'ADJ'), ('same', 'ADJ'), ('text', 'NOUN'), ('(', '.'), ('ie', 'ADJ'), ('.', '.'), ('plagiarize', 'VERB'), (')', '.'), ('about', 'ADP'), ('my', 'PRON'), ('#', '.'), ('COVIDVaccine', 'NOUN'), ('experience', 'NOUN'), ('-', '.'), ('only', 'ADV'), ('repl…', 'VERB'), ('https', 'NOUN'), (':', '.'), ('//t.co/9VHkdNm8sZ', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('BritishHIVAssoc', 'NOUN'), (':', '.'), ('...', '.'), ('lots', 'NOUN'), ('of', 'ADP'), ('#', '.'), ('COVID19', 'NOUN'), ('updates', 'NOUN'), ('and', 'CONJ'), ('advice', 'NOUN'), ('ranging', 'VERB'), ('from', 'ADP'), ('advice', 'NOUN'), ('around', 'ADP'), ('shielding', 'VERB'), (',', '.'), ('patient', 'ADJ'), ('concerns', 'NOUN'), (',', '.'), ('to', 'PRT'), ('vaccine', 'VERB'), ('updates', 'NOUN'), ('.', '.'), ('If…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('GovCanHealth', 'NOUN'), (':', '.'), ('Health', 'NOUN'), ('Canada', 'NOUN'), ('has', 'VERB'), ('authorized', 'VERB'), ('the', 'DET'), ('#', '.'), ('COVID19', 'NOUN'), ('vaccine', 'NOUN'), ('manufactured', 'VERB'), ('by', 'ADP'), ('AstraZeneca', 'NOUN'), (',', '.'), ('and', 'CONJ'), ('the', 'DET'), ('Serum', 'NOUN'), ('Institute', 'NOUN'), ('of', 'ADP'), ('India', 'NOUN'), ('’', 'NOUN'), ('s', 'VERB'), ('version…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('Found', 'NOUN'), ('my', 'PRON'), ('#', '.'), ('teacherbestie', 'ADJ'), ('@', 'NOUN'), ('WestsidehsTeach', 'NOUN'), ('in', 'ADP'), ('line', 'NOUN'), ('for', 'ADP'), ('our', 'PRON'), ('first', 'ADJ'), ('#', '.'), ('COVIDVaccine', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/hxMgLKVueY', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('nilikm', 'NOUN'), (':', '.'), ('So', 'ADV'), ('@', 'ADP'), ('GeneralHillier', 'NOUN'), ('says', 'VERB'), ('he', 'PRON'), ('can', 'VERB'), ('’', 'VERB'), ('t', 'ADJ'), ('imagine', 'VERB'), ('how', 'ADV'), ('this', 'DET'), ('rollout', 'NOUN'), ('could', 'VERB'), ('be', 'VERB'), ('better', 'ADJ'), ('in', 'ADP'), ('Ontario', 'NOUN'), ('.', '.'), ('Family', 'NOUN'), ('docs', 'VERB'), ('say', 'VERB'), ('it', 'PRON'), ("'s", 'VERB'), ('chaos', 'NOUN'), ('.', '.'), ('Whom', 'NOUN'), ('do', 'VERB'), ('you', 'PRON'), ('b…', 'VERB')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('WajidRizvi1', 'NOUN'), (':', '.'), ('Not', 'ADV'), ('how', 'ADV'), ('envisioned', 'ADJ'), ('my', 'PRON'), ('1st', 'NUM'), ('trip', 'NOUN'), ('to', 'PRT'), ('@', 'VERB'), ('GlobeLifeField', 'NOUN'), ('Getting', 'NOUN'), ('my', 'PRON'), ('Grandmother', 'NOUN'), ('vaccinated', 'VERB'), ('for', 'ADP'), ('Covid', 'NOUN'), ('19', 'NUM'), ('.', '.'), ('@', 'NOUN'), ('Rangers', 'NOUN'), ('@', 'NOUN'), ('CityOfArlingt…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('jacobthomas1960', 'NOUN'), (':', '.'), ('World', 'NOUN'), ("'s", 'PRT'), ('largest', 'ADJ'), ('vaccine', 'NOUN'), ('provider', 'NOUN'), ('.', '.'), ('#', '.'), ('CovidVaccine', 'NOUN'), ('#', '.'), ('IndiaFightsCorona', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/8J4jnOJ87w', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('#', '.'), ('CovidVaccine', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/VqBV4IRNEo', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('Y', 'NOUN'), ('’', 'NOUN'), ('ALL', 'NOUN'), ('I', 'PRON'), ('’', 'VERB'), ('M', 'NOUN'), ('COLD', 'NOUN'), ('AS', 'NOUN'), ('FUUCCKKKKK', 'NOUN'), ('#', '.'), ('COVIDVaccine', 'NOUN'), ('#', '.'), ('seconddose', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('Taleeb', 'NOUN'), (':', '.'), ('That', 'DET'), ("'s", 'VERB'), ('6.5M', 'NUM'), ('doses', 'NOUN'), ('in', 'ADP'), ('the', 'DET'), ('next', 'ADJ'), ('35', 'NUM'), ('days', 'NOUN'), (',', '.'), ('friends', 'NOUN'), ('.', '.'), ('Happier', 'NOUN'), ('days', 'NOUN'), ('are', 'VERB'), ('almost', 'ADV'), ('here', 'ADV'), ('.', '.'), ('Let', 'VERB'), ("'s", 'PRT'), ('stay', 'VERB'), ('safe', 'ADJ'), (',', '.'), ('and', 'CONJ'), ('do', 'VERB'), ('our', 'PRON'), ('part', 'NOUN'), ('.', '.'), ('#', '.'), ('WearAMask', 'NOUN'), ('#', '.'), ('Wa…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('GovCanHealth', 'NOUN'), (':', '.'), ('Health', 'NOUN'), ('Canada', 'NOUN'), ('has', 'VERB'), ('authorized', 'VERB'), ('the', 'DET'), ('#', '.'), ('COVID19', 'NOUN'), ('vaccine', 'NOUN'), ('manufactured', 'VERB'), ('by', 'ADP'), ('AstraZeneca', 'NOUN'), (',', '.'), ('and', 'CONJ'), ('the', 'DET'), ('Serum', 'NOUN'), ('Institute', 'NOUN'), ('of', 'ADP'), ('India', 'NOUN'), ('’', 'NOUN'), ('s', 'VERB'), ('version…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('ZeldinRecord', 'NOUN'), (':', '.'), ('@', 'NOUN'), ('christineguerc1', 'NOUN'), ('Awful—so', 'NOUN'), ('sorry', 'NOUN'), ('to', 'PRT'), ('hear', 'VERB'), ('that', 'DET'), ('.', '.'), ('Unfortunately', 'ADV'), (',', '.'), ('he', 'PRON'), ("'s", 'VERB'), ('not', 'ADV'), ('alone', 'ADV'), ('.', '.'), ('A', 'DET'), ('loophole', 'ADJ'), ('bans', 'VERB'), ('the', 'DET'), ('@', 'ADJ'), ('DeptVetAffairs', 'NOUN'), ('from', 'ADP'), ('giv…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('R_Good_Fellow_1', 'NOUN'), (':', '.'), ('Here', 'ADV'), ('is', 'VERB'), ('the', 'DET'), ('#', '.'), ('VAERS', 'NOUN'), ('report', 'NOUN'), ('for', 'ADP'), ('the', 'DET'), ('23', 'NUM'), ('year', 'NOUN'), ('old', 'ADJ'), ('who', 'PRON'), ('died', 'VERB'), ('after', 'ADP'), ('being', 'VERB'), ('given', 'VERB'), ('the', 'DET'), ('Moderna', 'NOUN'), ('#', '.'), ('covidvaccine', 'NOUN'), ('.', '.'), ('He', 'PRON'), ('was', 'VERB'), ('on', 'ADP'), ('15', 'NUM'), ('diffe…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('Only', 'ADV'), ('333k', 'NUM'), ('people', 'NOUN'), ('ahead', 'ADV'), ('of', 'ADP'), ('me', 'PRON'), ('in', 'ADP'), ('line', 'NOUN'), ('for', 'ADP'), ('#', '.'), ('COVIDVaccine', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/cohLEGW8vS', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('DVBergen', 'NOUN'), (':', '.'), ('Municipal', 'ADJ'), ('officials', 'NOUN'), ('in', 'ADP'), ('this', 'DET'), ('New', 'NOUN'), ('Jersey', 'NOUN'), ('city', 'NOUN'), ('are', 'VERB'), ('getting', 'VERB'), ('behind', 'ADP'), ('the', 'DET'), ('wheel', 'NOUN'), ('to', 'PRT'), ('bring', 'VERB'), ('residents', 'NOUN'), ('in', 'ADP'), ('need', 'NOUN'), ('of', 'ADP'), ('rides', 'NOUN'), ('to', 'PRT'), ('their', 'PRON'), ('COVID-1…', 'ADJ')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('USMC_O311', 'NOUN'), (':', '.'), ('There', 'DET'), ('are', 'VERB'), ('8', 'NUM'), ('million', 'NUM'), ('veterans', 'NOUN'), ('over', 'ADP'), ('the', 'DET'), ('age', 'NOUN'), ('of', 'ADP'), ('65', 'NUM'), ('.', '.'), ('The', 'DET'), ('@', 'NOUN'), ('DeptVetAffairs', 'NOUN'), ('has', 'VERB'), ('barely', 'ADV'), ('vaccinated', 'VERB'), ('1', 'NUM'), ('million', 'NUM'), ('of', 'ADP'), ('them', 'PRON'), ('.', '.'), ('There', 'DET'), ('are', 'VERB'), ('50…', 'NUM')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('PrincessZeeGirl', 'NOUN'), (':', '.'), ('Is', 'VERB'), ('#', '.'), ('Israel', 'NOUN'), ('denying', 'VERB'), ('the', 'DET'), ('#', '.'), ('Palestinians', 'NOUN'), ('the', 'DET'), ('#', '.'), ('COVIDVaccine', 'NOUN'), ('?', '.'), ('Find', 'NOUN'), ('out', 'PRT'), ('👇', 'ADJ'), ('https', 'NOUN'), (':', '.'), ('//t.co/GFuIT2brBS', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('Thrilled', 'VERB'), ('to', 'PRT'), ('see', 'VERB'), ('FDA', 'NOUN'), ('recommend', 'VERB'), ('J', 'NOUN'), ('&', 'CONJ'), ('amp', 'NOUN'), (';', '.'), ('J', 'NOUN'), ('#', '.'), ('COVIDVaccine', 'NOUN'), ('co-developed', 'ADJ'), ('by', 'ADP'), ('amazing', 'VERB'), ('colleagues', 'NOUN'), ('@', 'NOUN'), ('k_stephensonMD', 'VERB'), ('@', 'NOUN'), ('BarouchLab…', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/TSgghejhZB', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('I', 'PRON'), ('miss', 'VERB'), ('being', 'VERB'), ('invited', 'VERB'), ('for', 'ADP'), ('a', 'DET'), ('girls', 'NOUN'), ('night', 'NOUN'), ('.', '.'), ('Accepting', 'NOUN'), ('.', '.'), ('And', 'CONJ'), ('then', 'ADV'), ('canceling', 'VERB'), ('the', 'DET'), ('night', 'NOUN'), ('of', 'ADP'), ('.', '.'), ('🥺', 'NOUN'), ('I', 'PRON'), ('’', 'VERB'), ('ve', 'ADJ'), ('got', 'VERB'), ('all', 'DET'), ('my', 'PRON'), ('shots', 'NOUN'), ('now', 'ADV'), ('.', '.'), ('An…', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/g0PddnF7AR', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('Vaccine', 'NOUN'), ('#', '.'), ('COVIDVaccine', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/CynMKgIoQa', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('jacobthomas1960', 'NOUN'), (':', '.'), ('World', 'NOUN'), ("'s", 'PRT'), ('largest', 'ADJ'), ('vaccine', 'NOUN'), ('provider', 'NOUN'), ('.', '.'), ('#', '.'), ('CovidVaccine', 'NOUN'), ('#', '.'), ('IndiaFightsCorona', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/8J4jnOJ87w', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('Shakesnews_', 'NOUN'), (':', '.'), ('Vaccinations', 'NOUN'), ('at', 'ADP'), ('Oakland', 'NOUN'), ('’', 'NOUN'), ('s', 'VERB'), ('Coliseum', 'NOUN'), ('.', '.'), ('Efficient', 'NOUN'), (',', '.'), ('easy', 'ADJ'), (',', '.'), ('in', 'ADP'), ('and', 'CONJ'), ('out', 'ADP'), (',', '.'), ('no', 'DET'), ('issues', 'NOUN'), ('.', '.'), ('Watching', 'VERB'), ('so', 'ADV'), ('many', 'ADJ'), ('people', 'NOUN'), ('getting', 'VERB'), ('vaccinated', 'ADJ'), ('got…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('And', 'CONJ'), ('you', 'PRON'), ('think', 'VERB'), ('people', 'NOUN'), ('gon', 'VERB'), ('na', 'PRT'), ('take', 'VERB'), ('this', 'DET'), ('from', 'ADP'), ('fucking', 'VERB'), ('India', 'NOUN'), ('?', '.'), ('@', 'NOUN'), ('JustinTrudeau', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('name', 'NOUN'), ('of', 'ADP'), ('failure', 'NOUN'), ('!', '.'), ('Hope', 'NOUN'), ('you', 'PRON'), ('guys', 'VERB'), ('will', 'VERB'), ('br…', 'VERB'), ('https', 'NOUN'), (':', '.'), ('//t.co/S22xDF6tZ0', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('WRES_team', 'NOUN'), (':', '.'), ('With', 'ADP'), ('thanks', 'NOUN'), ('to', 'PRT'), ('@', 'VERB'), ('NHSEnglandLDN', 'NOUN'), ('for', 'ADP'), ('developing', 'VERB'), ('videos', 'NOUN'), ('in', 'ADP'), ('some', 'DET'), ('of', 'ADP'), ('the', 'DET'), ('most', 'ADV'), ('commonly', 'ADV'), ('spoken', 'ADJ'), ('non-English', 'ADJ'), ('languages', 'NOUN'), ('in', 'ADP'), ('#', '.'), ('London', 'NOUN'), ('and…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('Dissing', 'VERB'), ('Dallas', 'NOUN'), ('?', '.'), ('County', 'NOUN'), ('Judge', 'NOUN'), ('Clay', 'NOUN'), ('Jenkins', 'NOUN'), ('says', 'VERB'), ('the', 'DET'), ('state', 'NOUN'), ('is', 'VERB'), ('still', 'ADV'), ('shortchanging', 'VERB'), ('North', 'NOUN'), ('Texans', 'NOUN'), ('of', 'ADP'), ('their', 'PRON'), ('fair', 'ADJ'), ('share', 'NOUN'), ('of…', 'ADJ'), ('https', 'NOUN'), (':', '.'), ('//t.co/5c2FhtHrLf', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('SteveAdubato', 'NOUN'), (':', '.'), ('#', '.'), ('ThisWknd', 'NOUN'), ('on', 'ADP'), ('#', '.'), ('ThinkTankSA', 'NOUN'), ('@', 'NOUN'), ('ShereefElnahal', 'NOUN'), ('&', 'CONJ'), ('amp', 'NOUN'), (';', '.'), ('@', 'CONJ'), ('DrChrisMD', 'NOUN'), ('@', 'NOUN'), ('UnivHospNewark', 'NOUN'), (';', '.'), ('John', 'NOUN'), ('Harmon', 'NOUN'), ('@', 'NOUN'), ('AACCNJ', 'NOUN'), (';', '.'), ('and', 'CONJ'), ('@', 'VERB'), ('CarlosMedinaEsq', 'NOUN'), ('@', 'NOUN'), ('SHCCNJ…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('Only', 'ADV'), ('333k', 'NUM'), ('people', 'NOUN'), ('ahead', 'ADV'), ('of', 'ADP'), ('me', 'PRON'), ('in', 'ADP'), ('line', 'NOUN'), ('for', 'ADP'), ('#', '.'), ('COVIDVaccine', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/mLFbOnFFCk', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('USArmy', 'NOUN'), (':', '.'), ('Soldiers', 'NOUN'), ('for', 'ADP'), ('Life', 'NOUN'), ('🇺🇸', 'VERB'), ('A', 'NOUN'), ('veteran', 'NOUN'), ('receives', 'VERB'), ('the', 'DET'), ('#', '.'), ('CovidVaccine', 'NOUN'), ('from', 'ADP'), ('Spc', 'NOUN'), ('.', '.'), ('Alexis', 'NOUN'), ('Ruth', 'NOUN'), (',', '.'), ('a', 'DET'), ('member', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('@', 'NOUN'), ('MDNG', 'NOUN'), ('mobile', 'ADJ'), ('vaccination', 'NOUN'), ('supp…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('Ok', 'NOUN'), ('so', 'ADP'), ('the', 'DET'), ('#', '.'), ('COVIDVaccine', 'NOUN'), ('is', 'VERB'), ('big', 'ADJ'), ('government', 'NOUN'), ('as', 'ADP'), ('is', 'VERB'), ('the', 'DET'), ('roll', 'NOUN'), ('out', 'ADV'), ('and', 'CONJ'), ('free', 'ADJ'), ('shots', 'NOUN'), ('.', '.'), ('The', 'DET'), ('#', '.'), ('COVID19', 'NOUN'), ('bill', 'NOUN'), ('is', 'VERB'), ('big', 'ADJ'), ('government', 'NOUN'), ('.', '.'), ('B…', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/OlX1QIltGF', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('GovCanHealth', 'NOUN'), (':', '.'), ('Health', 'NOUN'), ('Canada', 'NOUN'), ('has', 'VERB'), ('authorized', 'VERB'), ('the', 'DET'), ('#', '.'), ('COVID19', 'NOUN'), ('vaccine', 'NOUN'), ('manufactured', 'VERB'), ('by', 'ADP'), ('AstraZeneca', 'NOUN'), (',', '.'), ('and', 'CONJ'), ('the', 'DET'), ('Serum', 'NOUN'), ('Institute', 'NOUN'), ('of', 'ADP'), ('India', 'NOUN'), ('’', 'NOUN'), ('s', 'VERB'), ('version…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('GovCanHealth', 'NOUN'), (':', '.'), ('Health', 'NOUN'), ('Canada', 'NOUN'), ('has', 'VERB'), ('authorized', 'VERB'), ('the', 'DET'), ('#', '.'), ('COVID19', 'NOUN'), ('vaccine', 'NOUN'), ('manufactured', 'VERB'), ('by', 'ADP'), ('AstraZeneca', 'NOUN'), (',', '.'), ('and', 'CONJ'), ('the', 'DET'), ('Serum', 'NOUN'), ('Institute', 'NOUN'), ('of', 'ADP'), ('India', 'NOUN'), ('’', 'NOUN'), ('s', 'VERB'), ('version…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('thetonymichaels', 'NOUN'), (':', '.'), ('Let', 'VERB'), ('’', 'NOUN'), ('s', 'VERB'), ('Talk', 'NOUN'), ('🎤', 'NOUN'), ('Booger', 'NOUN'), ('Sooger', 'NOUN'), ('#', '.'), ('CocaineDonJr', 'NOUN'), ('#', '.'), ('DonJr', 'NOUN'), ('#', '.'), ('vaccine', 'NOUN'), ('#', '.'), ('COVID19', 'NOUN'), ('#', '.'), ('CovidVaccine', 'NOUN'), ('#', '.'), ('TeachersUnion', 'NOUN'), ('#', '.'), ('OpenSchoolsNow', 'NOUN'), ('#', '.'), ('cocain…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('PrincessZeeGirl', 'NOUN'), (':', '.'), ('Is', 'VERB'), ('#', '.'), ('Israel', 'NOUN'), ('denying', 'VERB'), ('the', 'DET'), ('#', '.'), ('Palestinians', 'NOUN'), ('the', 'DET'), ('#', '.'), ('COVIDVaccine', 'NOUN'), ('?', '.'), ('Find', 'NOUN'), ('out', 'PRT'), ('👇', 'ADJ'), ('https', 'NOUN'), (':', '.'), ('//t.co/GFuIT2brBS', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'ADJ'), ('BSBreastCancer', 'NOUN'), (':', '.'), ('@', 'ADJ'), ('silke4senate', 'NOUN'), ('@', 'NOUN'), ('abcdiagnosis', 'NOUN'), ('@', 'NOUN'), ('JJ_locked', 'NOUN'), ('@', 'NOUN'), ('AMJohnston1315', 'NOUN'), ('@', 'NOUN'), ('JulieMeryl09', 'NOUN'), ('@', 'NOUN'), ('fitwithjanice', 'NOUN'), ('@', 'NOUN'), ('fiestyivy', 'NOUN'), ('@', 'NOUN'), ('drawstickpeople', 'NOUN'), ('@', 'NOUN'), ('AmyDem…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'ADJ'), ('kentcrexreacts', 'NOUN'), (':', '.'), ('2nd', 'NUM'), ('dose', 'NOUN'), ('of', 'ADP'), ('vaccine', 'ADJ'), ('✅', 'NOUN'), ('~Vaccinated-Rex', 'NOUN'), ('😉', 'NOUN'), ('#', '.'), ('vaccinated', 'VERB'), ('#', '.'), ('COVID19Vaccine', 'NOUN'), ('#', '.'), ('covidvaccine', 'NOUN'), ('#', '.'), ('Moderna', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/3a27P3SrTT', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('GovCanHealth', 'NOUN'), (':', '.'), ('Health', 'NOUN'), ('Canada', 'NOUN'), ('has', 'VERB'), ('authorized', 'VERB'), ('the', 'DET'), ('#', '.'), ('COVID19', 'NOUN'), ('vaccine', 'NOUN'), ('manufactured', 'VERB'), ('by', 'ADP'), ('AstraZeneca', 'NOUN'), (',', '.'), ('and', 'CONJ'), ('the', 'DET'), ('Serum', 'NOUN'), ('Institute', 'NOUN'), ('of', 'ADP'), ('India', 'NOUN'), ('’', 'NOUN'), ('s', 'VERB'), ('version…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('IdaMHolguin', 'NOUN'), (':', '.'), ('I', 'PRON'), ('was', 'VERB'), ('fortunate', 'ADJ'), ('enough', 'ADV'), ('to', 'PRT'), ('not', 'ADV'), ('have', 'VERB'), ('any', 'DET'), ('side', 'NOUN'), ('effects', 'NOUN'), ('with', 'ADP'), ('the', 'DET'), ('first', 'ADJ'), ('dose', 'NOUN'), (',', '.'), ('but', 'CONJ'), ('man', 'NOUN'), ('this', 'DET'), ('second', 'ADJ'), ('dose', 'NOUN'), ('is', 'VERB'), ('kicking', 'VERB'), ('my', 'PRON'), ('butt', 'NOUN'), ('!', '.'), ('Feve…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('PSPC_SPAC', 'NOUN'), (':', '.'), ('Canada', 'NOUN'), ('has', 'VERB'), ('secured', 'VERB'), ('2', 'NUM'), ('million', 'NUM'), ('additional', 'ADJ'), ('doses', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('@', 'NOUN'), ('GovCanHealth', 'NOUN'), ('authorized', 'VERB'), ('AstraZeneca', 'NOUN'), ('#', '.'), ('COVIDvaccine', 'NOUN'), ('.', '.'), ('The', 'DET'), ('first', 'ADJ'), ('500,000', 'NUM'), ('d…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('This', 'DET'), ('!', '.'), ('#', '.'), ('India', 'NOUN'), ('#', '.'), ('COVIDVaccine', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/gqLxmvmqZe', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('PIBShimla', 'NOUN'), (':', '.'), ('#', '.'), ('LargestVaccineDrive', 'VERB'), ('The', 'DET'), ('medical', 'ADJ'), ('community', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('#', '.'), ('frontlineworkers', 'NOUN'), ('to', 'PRT'), ('come', 'VERB'), ('forward', 'ADV'), ('and', 'CONJ'), ('take', 'VERB'), ('the', 'DET'), ('#', '.'), ('COVIDvaccine', 'NOUN'), ('.', '.'), ('Let', 'VERB'), ('us', 'PRON'), ('all…', 'VERB')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('GovCanHealth', 'NOUN'), (':', '.'), ('Health', 'NOUN'), ('Canada', 'NOUN'), ('has', 'VERB'), ('authorized', 'VERB'), ('the', 'DET'), ('#', '.'), ('COVID19', 'NOUN'), ('vaccine', 'NOUN'), ('manufactured', 'VERB'), ('by', 'ADP'), ('AstraZeneca', 'NOUN'), (',', '.'), ('and', 'CONJ'), ('the', 'DET'), ('Serum', 'NOUN'), ('Institute', 'NOUN'), ('of', 'ADP'), ('India', 'NOUN'), ('’', 'NOUN'), ('s', 'VERB'), ('version…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('PIBShimla', 'NOUN'), (':', '.'), ('#', '.'), ('LargestVaccineDrive', 'VERB'), ('The', 'DET'), ('medical', 'ADJ'), ('community', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('#', '.'), ('frontlineworkers', 'NOUN'), ('to', 'PRT'), ('come', 'VERB'), ('forward', 'ADV'), ('and', 'CONJ'), ('take', 'VERB'), ('the', 'DET'), ('#', '.'), ('COVIDvaccine', 'NOUN'), ('.', '.'), ('Let', 'VERB'), ('us', 'PRON'), ('all…', 'VERB')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('DrShaneRRR', 'NOUN'), (':', '.'), ('I', 'PRON'), ('want', 'VERB'), ('to', 'PRT'), ('see', 'VERB'), ('a', 'DET'), ('#', '.'), ('COVIDVaccine', 'NOUN'), ('counter', 'NOUN'), ('from', 'ADP'), ('@', 'ADJ'), ('abcnews', 'NOUN'), ('for', 'ADP'), ('Australia', 'NOUN'), ('.', '.'), ('I', 'PRON'), ('want', 'VERB'), ('to', 'PRT'), ('celebrate', 'VERB'), ('the', 'DET'), ('successes', 'NOUN'), ('of', 'ADP'), ('this', 'DET'), ('historical', 'ADJ'), ('ca…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('MarilynHeineMD', 'NOUN'), (':', '.'), ('.\u2066', 'ADJ'), ('@', 'NOUN'), ('AmerMedicalAssn\u2069', 'NOUN'), ('urges', 'VERB'), ('@', 'NOUN'), ('WhiteHouse', 'NOUN'), ('to', 'PRT'), ('include', 'VERB'), ('physician', 'ADJ'), ('offices', 'NOUN'), ('in', 'ADP'), ('#', '.'), ('CovidVaccine', 'NOUN'), ('distribution', 'NOUN'), ('and', 'CONJ'), ('delivery', 'NOUN'), ('plans.…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('gamhcarercentre', 'NOUN'), (':', '.'), ('#', '.'), ('Glasgowcarers', 'VERB'), ('the', 'DET'), ('#', '.'), ('CovidVaccine', 'NOUN'), ('is', 'VERB'), ('currently', 'ADV'), ('being', 'VERB'), ('rolled', 'VERB'), ('out', 'PRT'), (',', '.'), ('please', 'VERB'), ('contact', 'VERB'), ('your', 'PRON'), ('local', 'ADJ'), ('Carers', 'NOUN'), ('Centre', 'NOUN'), ('for', 'ADP'), ('up', 'ADV'), ('to', 'PRT'), ('date…', 'VERB')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('welosthim', 'NOUN'), (':', '.'), ('People', 'NOUN'), ('with', 'ADP'), ('comorbidities', 'NOUN'), ('in', 'ADP'), ('aged', 'VERB'), ('care', 'NOUN'), ('die', 'NOUN'), ('after', 'ADP'), ('contracting', 'VERB'), ('#', '.'), ('COVID19', 'NOUN'), ('we', 'PRON'), ('lockdown', 'VERB'), ('destroying', 'VERB'), ('lives', 'NOUN'), ('&', 'CONJ'), ('amp', 'NOUN'), (';', '.'), ('livelihoods', 'NOUN'), (',', '.'), ('yet', 'ADV'), ('when', 'ADV'), ('p…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('अरे', 'NOUN'), ('भिखारिन', 'NOUN'), (',', '.'), ('भीख', 'NOUN'), ('में', 'NOUN'), ('मिली', 'NOUN'), ('दवाई', 'NOUN'), ('का', 'NOUN'), ('Refund', 'NOUN'), ('कौन', 'NOUN'), ('मांगता', 'NOUN'), ('है', 'NOUN'), ('?', '.'), ('😆😆', 'NOUN'), ('@', 'NOUN'), ('J0zigirl', 'NOUN'), ('All', 'NOUN'), ('countries', 'NOUN'), ('mentioned', 'VERB'), ('have', 'VERB'), ('been', 'VERB'), ('given…', 'ADJ'), ('https', 'NOUN'), (':', '.'), ('//t.co/a1hvFeOpb5', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('@', 'NOUN'), ('JerrySoucyRN', 'NOUN'), ('Here', 'ADV'), ('is', 'VERB'), ('14', 'NUM'), ('days', 'NOUN'), ('of', 'ADP'), ('my', 'PRON'), ('life-', 'ADJ'), ('Wrote', 'NOUN'), ('testimony', 'NOUN'), ('for', 'ADP'), ('HB', 'NOUN'), ('2510', 'NUM'), ('Secure', 'NOUN'), ('Storage', 'NOUN'), ('Medical', 'NOUN'), ('Lead', 'NOUN'), ('for', 'ADP'), ('2…', 'NUM'), ('https', 'NOUN'), (':', '.'), ('//t.co/Kt3OsK6La5', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('So', 'ADV'), ('happy', 'ADJ'), ('for', 'ADP'), ('my', 'PRON'), ('hubs', 'NOUN'), ('!', '.'), ('Second', 'ADJ'), ('@', 'NOUN'), ('pfizer', 'NOUN'), ('#', '.'), ('COVIDVaccine', 'NOUN'), ('DONE', 'NOUN'), ('.', '.'), ('(', '.'), ('I', 'PRON'), ('can', 'VERB'), ('sleep', 'VERB'), ('soundly', 'ADV'), ('next', 'ADJ'), ('to', 'PRT'), ('him', 'PRON'), ('...', '.'), ('I', 'PRON'), ('think', 'VERB'), ('🤔', 'ADV'), (')', '.'), ('https', 'NOUN'), (':', '.'), ('//t.co/ohctiYw8Hf', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('A', 'DET'), ('helluva', 'ADJ'), ('way', 'NOUN'), ('to', 'PRT'), ('end', 'VERB'), ('week', 'NOUN'), ('!', '.'), ('👏🙌', 'CONJ'), ('💥', 'VERB'), ('One', 'NUM'), ('down', 'ADV'), ('.', '.'), ('One', 'NUM'), ('to', 'PRT'), ('go', 'VERB'), ('!', '.'), ('💥', 'NOUN'), ('THANK', 'NOUN'), ('YOU', 'NOUN'), ('#', '.'), ('scientists', 'NOUN'), ('and', 'CONJ'), ('#', '.'), ('medical', 'ADJ'), ('experts', 'NOUN'), ('!', '.'), ('🙏🏼…', 'ADJ'), ('https', 'NOUN'), (':', '.'), ('//t.co/mLUdorWh4m', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('@', 'ADJ'), ('ScottMorrisonMp', 'NOUN'), ('advises', 'VERB'), ('we', 'PRON'), ('should', 'VERB'), ('expect', 'VERB'), ('there', 'DET'), ('to', 'PRT'), ('be', 'VERB'), ('teething', 'VERB'), ('problems', 'NOUN'), ('as', 'ADP'), ('this', 'DET'), ('is', 'VERB'), ('early', 'ADJ'), ('days', 'NOUN'), ('in', 'ADP'), ('the', 'DET'), ('#', '.'), ('COVIDVaccine…', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/aJKS4cWt49', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('prodefkohima', 'NOUN'), (':', '.'), ('While', 'ADP'), ('the', 'DET'), ('#', '.'), ('CovidVaccine', 'NOUN'), ('is', 'VERB'), ('NOW', 'NOUN'), ('available', 'ADJ'), ('it', 'PRON'), ('is', 'VERB'), ('critical', 'ADJ'), ('that', 'ADP'), ('all', 'DET'), ('of', 'ADP'), ('us', 'PRON'), ('continue', 'VERB'), ('to', 'PRT'), ('follow', 'VERB'), ('all', 'DET'), ('the', 'DET'), ('#', '.'), ('COVID', 'NOUN'), ('Appropriate', 'NOUN'), ('Beha…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('So', 'ADP'), ('the', 'DET'), ('amazing', 'ADJ'), ('team', 'NOUN'), ('at', 'ADP'), ('https', 'NOUN'), (':', '.'), ('//t.co/zFvTfvagja', 'NOUN'), ('managed', 'VERB'), ('to', 'PRT'), ('get', 'VERB'), ('my', 'PRON'), ('father', 'NOUN'), ('a', 'DET'), ('vaccine', 'NOUN'), ('appointment', 'NOUN'), ('for', 'ADP'), ('tomorrow', 'NOUN'), ('.', '.'), ('Please…', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/imUw72YaVU', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('Sure', 'ADV'), (',', '.'), ('how', 'ADV'), ('it', 'PRON'), ('feels', 'VERB'), ('to', 'PRT'), ('be', 'VERB'), ('rich', 'ADJ'), ('is', 'VERB'), ('REALLY', 'NOUN'), ('what', 'PRON'), ('’', 'NOUN'), ('s', 'NOUN'), ('on', 'ADP'), ('everyone', 'NOUN'), ('’', 'ADJ'), ('s', 'NOUN'), ('mind', 'NOUN'), (',', '.'), ('and', 'CONJ'), ('not', 'ADV'), ('how', 'ADV'), ('“', 'ADJ'), ('giving', 'VERB'), ('money', 'NOUN'), ('back', 'ADV'), ('in', 'ADP'), ('a', 'DET'), ('smart', 'ADJ'), ('way', 'NOUN'), ('”', 'NOUN'), ('s…', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/uYABYVa0DL', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('jacobthomas1960', 'NOUN'), (':', '.'), ('World', 'NOUN'), ("'s", 'PRT'), ('largest', 'ADJ'), ('vaccine', 'NOUN'), ('provider', 'NOUN'), ('.', '.'), ('#', '.'), ('CovidVaccine', 'NOUN'), ('#', '.'), ('IndiaFightsCorona', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/8J4jnOJ87w', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('``', '.'), ('Transatlantic', 'ADJ'), ('Trade', 'NOUN'), ('|', 'NOUN'), ('US', 'NOUN'), ('and', 'CONJ'), ('Europe', 'NOUN'), ('–', 'NOUN'), ('Week', 'NOUN'), ('of', 'ADP'), ('February', 'NOUN'), ('22', 'NUM'), (',', '.'), ('2021', 'NUM'), ("''", '.'), ('https', 'NOUN'), (':', '.'), ('//t.co/2x8AILCkyl', 'ADJ'), ('#', '.'), ('UK', 'NOUN'), ('#', '.'), ('SpaceAgencies', 'NOUN'), ('#', '.'), ('COVIDVaccine', 'NOUN'), ('@', 'NOUN'), ('SPB_Global', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('GovCanHealth', 'NOUN'), (':', '.'), ('Health', 'NOUN'), ('Canada', 'NOUN'), ('has', 'VERB'), ('authorized', 'VERB'), ('the', 'DET'), ('#', '.'), ('COVID19', 'NOUN'), ('vaccine', 'NOUN'), ('manufactured', 'VERB'), ('by', 'ADP'), ('AstraZeneca', 'NOUN'), (',', '.'), ('and', 'CONJ'), ('the', 'DET'), ('Serum', 'NOUN'), ('Institute', 'NOUN'), ('of', 'ADP'), ('India', 'NOUN'), ('’', 'NOUN'), ('s', 'VERB'), ('version…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('nilikm', 'NOUN'), (':', '.'), ('So', 'ADV'), ('@', 'ADP'), ('GeneralHillier', 'NOUN'), ('says', 'VERB'), ('he', 'PRON'), ('can', 'VERB'), ('’', 'VERB'), ('t', 'ADJ'), ('imagine', 'VERB'), ('how', 'ADV'), ('this', 'DET'), ('rollout', 'NOUN'), ('could', 'VERB'), ('be', 'VERB'), ('better', 'ADJ'), ('in', 'ADP'), ('Ontario', 'NOUN'), ('.', '.'), ('Family', 'NOUN'), ('docs', 'VERB'), ('say', 'VERB'), ('it', 'PRON'), ("'s", 'VERB'), ('chaos', 'NOUN'), ('.', '.'), ('Whom', 'NOUN'), ('do', 'VERB'), ('you', 'PRON'), ('b…', 'VERB')]
# <FreqDist with 8 samples and 33 outcomes>
# [('If', 'ADP'), ('you', 'PRON'), ('get', 'VERB'), ('your', 'PRON'), ('#', '.'), ('COVIDVaccine', 'NOUN'), ('you', 'PRON'), ('will', 'VERB'), ('be', 'VERB'), ('microchipped..', 'VERB'), ('THEY', 'NOUN'), ('will', 'VERB'), ('be', 'VERB'), ('following', 'VERB'), ('YOU', 'PRON'), ('!', '.'), ('!', '.'), ('https', 'NOUN'), (':', '.'), ('//t.co/X0FQ9d3doz', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('@', 'NOUN'), ('CBCAlerts', 'NOUN'), ('Cool', 'NOUN'), ('.', '.'), ('How', 'NOUN'), ('many', 'ADJ'), ('decades', 'NOUN'), ('before', 'ADP'), ('we', 'PRON'), ('get', 'VERB'), ('any', 'DET'), ('?', '.'), ('And', 'CONJ'), ('then', 'ADV'), ('botch', 'VERB'), ('the', 'DET'), ('plans', 'NOUN'), ('to', 'PRT'), ('distribute', 'VERB'), ('and', 'CONJ'), ('administer', 'VERB'), ('them', 'PRON'), ('?', '.'), ('Do…', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/kAVTRhBWlJ', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('Poll', 'NOUN'), (':', '.'), ('Is', 'VERB'), ('your', 'PRON'), ('college/university', 'NOUN'), ('asking', 'VERB'), ('you', 'PRON'), ('for', 'ADP'), ('documentation', 'NOUN'), ('that', 'ADP'), ('you', 'PRON'), ('have', 'VERB'), ('received', 'VERB'), ('the', 'DET'), ('#', '.'), ('covidvaccine', 'NOUN'), ('?', '.'), ('#', '.'), ('highered', 'VERB')]
# <FreqDist with 8 samples and 33 outcomes>
# [('@', 'ADJ'), ('TNChapterACS', 'NOUN'), ('@', 'NOUN'), ('UTKnoxSurgery', 'NOUN'), ('@', 'NOUN'), ('utmedicalcenter', 'ADV'), ('Great', 'NOUN'), ('job', 'NOUN'), ('Dr.', 'NOUN'), ('Gray', 'NOUN'), ('and', 'CONJ'), ('team', 'NOUN'), ('!', '.'), ('Proud', 'NOUN'), ('to', 'PRT'), ('see', 'VERB'), ('@', 'ADJ'), ('utmedicalcenter', 'NOUN'), ('going', 'VERB'), ('out…', 'ADJ'), ('https', 'NOUN'), (':', '.'), ('//t.co/4l1WKKytPw', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('jacobthomas1960', 'NOUN'), (':', '.'), ('World', 'NOUN'), ("'s", 'PRT'), ('largest', 'ADJ'), ('vaccine', 'NOUN'), ('provider', 'NOUN'), ('.', '.'), ('#', '.'), ('CovidVaccine', 'NOUN'), ('#', '.'), ('IndiaFightsCorona', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/8J4jnOJ87w', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('DrNinaRadcliff', 'NOUN'), (':', '.'), ('Now', 'ADV'), ('’', 'VERB'), ('s', 'VERB'), ('the', 'DET'), ('time', 'NOUN'), ('for', 'ADP'), ('#', '.'), ('doctors', 'NOUN'), (',', '.'), ('#', '.'), ('Americans', 'NOUN'), ('to', 'PRT'), ('double-down', 'ADJ'), (',', '.'), ('triple-down', 'ADJ'), ('on', 'ADP'), ('#', '.'), ('preventive', 'ADJ'), ('care—', 'NOUN'), ('#', '.'), ('preventing', 'VERB'), ('#', '.'), ('problems', 'NOUN'), ('instead', 'ADV'), ('o…', 'VERB')]
# <FreqDist with 8 samples and 33 outcomes>
# [('Yes', 'X'), ('!', '.'), ('I', 'PRON'), ('have', 'VERB'), ('a', 'DET'), ('small', 'ADJ'), ('number', 'NOUN'), ('of', 'ADP'), ('patients', 'NOUN'), ('who', 'PRON'), ('refuse', 'VERB'), ('all', 'DET'), ('other', 'ADJ'), ('vaccines', 'NOUN'), ('who', 'PRON'), ('have', 'VERB'), ('received', 'VERB'), ('the', 'DET'), ('#', '.'), ('COVIDVaccine…', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/zWpsVQCHX8', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('I', 'PRON'), ('ask', 'VERB'), ('myself', 'PRON'), ('who', 'PRON'), ('at', 'ADP'), ('the', 'DET'), ('@', 'ADJ'), ('CDCgov', 'NOUN'), ('does', 'VERB'), ("n't", 'ADV'), ('put', 'VERB'), ('#', '.'), ('cancer', 'NOUN'), ('and', 'CONJ'), ('vulnerable', 'ADJ'), ('in', 'ADP'), ('the', 'DET'), ('same', 'ADJ'), ('sentence', 'NOUN'), ('when', 'ADV'), ('speaking', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('#', '.'), ('COVID…', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/4gIpgv4hwo', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('MarilynHeineMD', 'NOUN'), (':', '.'), ('.\u2066', 'ADJ'), ('@', 'NOUN'), ('AmerMedicalAssn\u2069', 'NOUN'), ('urges', 'VERB'), ('@', 'NOUN'), ('WhiteHouse', 'NOUN'), ('to', 'PRT'), ('include', 'VERB'), ('physician', 'ADJ'), ('offices', 'NOUN'), ('in', 'ADP'), ('#', '.'), ('CovidVaccine', 'NOUN'), ('distribution', 'NOUN'), ('and', 'CONJ'), ('delivery', 'NOUN'), ('plans.…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('Well', 'ADV'), ('done', 'VERB'), ('and', 'CONJ'), ('thank', 'VERB'), ('you', 'PRON'), ('@', 'ADJ'), ('MarisePayne', 'NOUN'), ('.', '.'), ('It', 'PRON'), ('is', 'VERB'), ('so', 'ADV'), ('important', 'ADJ'), ('we', 'PRON'), ('ALL', 'DET'), ('pull', 'VERB'), ('in', 'ADP'), ('the', 'DET'), ('same', 'ADJ'), ('direction', 'NOUN'), ('in', 'ADP'), ('reducing', 'VERB'), ('vaccine', 'NOUN'), ('hesi…', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/FcF7gfXK3x', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'CONJ'), ('Refugees', 'NOUN'), (':', '.'), ('@', 'NOUN'), ('WHO', 'PRON'), ('@', 'VERB'), ('DrMikeRyan', 'NOUN'), ('@', 'NOUN'), ('FilippoGrandi', 'NOUN'), ('Including', 'NOUN'), ('refugees', 'NOUN'), ('in', 'ADP'), ('national', 'ADJ'), ('#', '.'), ('COVIDvaccine', 'NOUN'), ('plans', 'VERB'), ('is', 'VERB'), ('key', 'ADJ'), ('to', 'PRT'), ('ensuring', 'VERB'), ('we', 'PRON'), ('protect', 'VERB'), ('as', 'ADP'), ('many', 'ADJ'), ('peop…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('EbonyJHilton_MD', 'NOUN'), (':', '.'), ('The', 'DET'), ('fact', 'NOUN'), ('that', 'ADP'), ('this', 'DET'), ('...', '.'), ('person', 'NOUN'), ('...', '.'), ('obtained', 'VERB'), ('a', 'DET'), ('#', '.'), ('COVIDvaccine', 'NOUN'), ('annoys', 'VERB'), ('me', 'PRON'), ('more', 'ADJ'), ('than', 'ADP'), ('anything', 'NOUN'), ('else', 'ADV'), ('.', '.'), ('@', 'ADJ'), ('GovRonDeSantis', 'NOUN'), (',', '.'), ('@', 'NOUN'), ('tedcruz…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('MarilynHeineMD', 'NOUN'), (':', '.'), ('.\u2066', 'ADJ'), ('@', 'NOUN'), ('AmerMedicalAssn\u2069', 'NOUN'), ('urges', 'VERB'), ('@', 'NOUN'), ('WhiteHouse', 'NOUN'), ('to', 'PRT'), ('include', 'VERB'), ('physician', 'ADJ'), ('offices', 'NOUN'), ('in', 'ADP'), ('#', '.'), ('CovidVaccine', 'NOUN'), ('distribution', 'NOUN'), ('and', 'CONJ'), ('delivery', 'NOUN'), ('plans.…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('New', 'NOUN'), ('#', '.'), ('WeekinReview', 'NOUN'), ('#', '.'), ('Biden', 'NOUN'), ('#', '.'), ('COVID19', 'NOUN'), ('#', '.'), ('COVIDVaccine', 'NOUN'), ('#', '.'), ('FederalReserve', 'NOUN'), ('#', '.'), ('WallStreet', 'NOUN'), ('#', '.'), ('bondmarket', 'NOUN'), ('#', '.'), ('Trump', 'NOUN'), ('#', '.'), ('CPAC2021', 'NOUN'), ('#', '.'), ('Iran…', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/xAHgh1lFMU', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('#', '.'), ('CovidVaccine', 'NOUN'), ('#', '.'), ('PharmacyoftheWorld', 'NOUN'), ('#', '.'), ('IndiaforHumanity', 'NOUN'), ('#', '.'), ('AffordableVaccines4All', 'NOUN'), ('@', 'NOUN'), ('MEAIndia', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/5LIAeslKoS', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('.\u2066', 'ADJ'), ('@', 'NOUN'), ('AmerMedicalAssn\u2069', 'NOUN'), ('urges', 'VERB'), ('@', 'NOUN'), ('WhiteHouse', 'NOUN'), ('to', 'PRT'), ('include', 'VERB'), ('physician', 'ADJ'), ('offices', 'NOUN'), ('in', 'ADP'), ('#', '.'), ('CovidVaccine', 'NOUN'), ('distribution', 'NOUN'), ('and', 'CONJ'), ('delivery', 'NOUN'), ('plans…', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/OVRHnkuoks', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('@', 'ADJ'), ('GoHealio', 'NOUN'), ('@', 'NOUN'), ('TheGrahamCenter', 'NOUN'), ('@', 'NOUN'), ('PCPCC', 'NOUN'), ('@', 'NOUN'), ('DarilynMoyer', 'NOUN'), ('@', 'NOUN'), ('ACPinternists', 'NOUN'), ('@', 'NOUN'), ('DrAngelicaDrPH', 'NOUN'), ('@', 'NOUN'), ('wearewhi1214', 'VERB'), ('@', 'NOUN'), ('lloydmichener…', 'ADJ'), ('https', 'NOUN'), (':', '.'), ('//t.co/an8TdESRtr', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('GovCanHealth', 'NOUN'), (':', '.'), ('Health', 'NOUN'), ('Canada', 'NOUN'), ('has', 'VERB'), ('authorized', 'VERB'), ('the', 'DET'), ('#', '.'), ('COVID19', 'NOUN'), ('vaccine', 'NOUN'), ('manufactured', 'VERB'), ('by', 'ADP'), ('AstraZeneca', 'NOUN'), (',', '.'), ('and', 'CONJ'), ('the', 'DET'), ('Serum', 'NOUN'), ('Institute', 'NOUN'), ('of', 'ADP'), ('India', 'NOUN'), ('’', 'NOUN'), ('s', 'VERB'), ('version…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('khansh', 'NOUN'), (':', '.'), ('Only', 'ADV'), ('11', 'NUM'), ('%', 'NOUN'), ('of', 'ADP'), ('Medical', 'ADJ'), ('professionals', 'NOUN'), ('in', 'ADP'), ('India', 'NOUN'), ('agreed', 'VERB'), ('to', 'PRT'), ('take', 'VERB'), ('the', 'DET'), ('Covaxin', 'NOUN'), ('shot', 'NOUN'), ('(', '.'), ('manufactured', 'VERB'), ('by', 'ADP'), ('Bharat', 'NOUN'), ('Biotech', 'NOUN'), (')', '.'), ('.', '.'), ('The', 'DET'), ('rest', 'NOUN'), ('opted', 'VERB'), ('for…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('Only', 'ADV'), ('11', 'NUM'), ('%', 'NOUN'), ('of', 'ADP'), ('Medical', 'ADJ'), ('professionals', 'NOUN'), ('in', 'ADP'), ('India', 'NOUN'), ('agreed', 'VERB'), ('to', 'PRT'), ('take', 'VERB'), ('the', 'DET'), ('Covaxin', 'NOUN'), ('shot', 'NOUN'), ('(', '.'), ('manufactured', 'VERB'), ('by', 'ADP'), ('Bharat', 'NOUN'), ('Biotech', 'NOUN'), (')', '.'), ('.', '.'), ('The', 'DET'), ('re…', 'ADJ'), ('https', 'NOUN'), (':', '.'), ('//t.co/CVqIm37R7O', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('@', 'ADJ'), ('CNY315_', 'NOUN'), ('@', 'NOUN'), ('CEJRyanMcMahon', 'NOUN'), ('@', 'NOUN'), ('ClaudiaTenney', 'NOUN'), ('@', 'NOUN'), ('RepJohnKatko', 'NOUN'), ('@', 'NOUN'), ('YoungKimCA', 'NOUN'), ('@', 'NOUN'), ('aslavitt46', 'VERB'), ('@', 'NOUN'), ('JoeBiden', 'NOUN'), ('@', 'NOUN'), ('WHCOS', 'NOUN'), ("Today's…", 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/MRWBx4DUtZ', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('So', 'ADV'), ('excited', 'ADJ'), ('!', '.'), ('!', '.'), ('!', '.'), ('🙌🏼', 'ADJ'), ('Registration', 'NOUN'), ('confirmed', 'VERB'), ('for', 'ADP'), ('my', 'PRON'), ('first', 'ADJ'), ('Fauci', 'NOUN'), ('Ouchie', 'NOUN'), ('next', 'ADJ'), ('week', 'NOUN'), ('!', '.'), ('💉🦠\U0001fa79🏥', 'NOUN'), ('.', '.'), ('#', '.'), ('FauciOuchie', 'NOUN'), ('#', '.'), ('covid19…', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/paQCkbe0Vt', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('#', '.'), ('LargestVaccineDrive', 'NOUN'), ('The', 'DET'), ('medical', 'ADJ'), ('community', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('#', '.'), ('frontlineworkers', 'NOUN'), ('to', 'PRT'), ('come', 'VERB'), ('forward', 'ADV'), ('and', 'CONJ'), ('take', 'VERB'), ('the', 'DET'), ('#', '.'), ('COVIDvaccine', 'NOUN'), ('.', '.'), ('L…', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/8rJxvcbyPg', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('#', '.'), ('COVIDVaccine', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/RSypTHWI8O', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('cna006', 'NOUN'), (':', '.'), ('@', 'ADJ'), ('jpquinteros', 'NOUN'), ('@', 'VERB'), ('marklewismd', 'ADJ'), ('😂', 'NOUN'), ('thanks', 'NOUN'), ('for', 'ADP'), ('the', 'DET'), ('laugh', 'NOUN'), ('!', '.'), ('Let', 'VERB'), ('’', 'NOUN'), ('s', 'VERB'), ('spread', 'NOUN'), ('good', 'ADJ'), ('info', 'NOUN'), ('about', 'ADP'), ('#', '.'), ('COVIDVaccine', 'NOUN'), ('through', 'ADP'), ('whatever', 'DET'), ('ways', 'NOUN'), ('possible', 'ADJ'), ('!', '.'), ('Hu…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('Feeling', 'VERB'), ('down', 'PRT'), ('?', '.'), ('Start', 'VERB'), ('your', 'PRON'), ('weekend', 'NOUN'), ('with', 'ADP'), ('this', 'DET'), ('heartwarming', 'VERB'), ('account', 'NOUN'), ('of', 'ADP'), ('our', 'PRON'), ('heroes', 'NOUN'), ('from', 'ADP'), ('#', '.'), ('TeamCVS', 'NOUN'), ('&', 'CONJ'), ('amp', 'NOUN'), (';', '.'), ('other', 'ADJ'), ('health', 'NOUN'), ('care', 'NOUN'), ('lea…', 'ADJ'), ('https', 'NOUN'), (':', '.'), ('//t.co/EryntLCuVy', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('#', '.'), ('LargestVaccineDrive', 'NOUN'), ('The', 'DET'), ('medical', 'ADJ'), ('community', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('#', '.'), ('frontlineworkers', 'NOUN'), ('to', 'PRT'), ('come', 'VERB'), ('forward', 'ADV'), ('and', 'CONJ'), ('take', 'VERB'), ('the', 'DET'), ('#', '.'), ('COVIDvaccine', 'NOUN'), ('.', '.'), ('L…', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/iriCHtorVw', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('#', '.'), ('COVIDVaccine', 'NOUN'), ('tomorrow', 'NOUN'), ('.', '.'), ('It', 'PRON'), ('feel', 'VERB'), ('like', 'ADP'), ('Christmas', 'NOUN'), ('Eve', 'NOUN'), ('.', '.'), ('@', 'NOUN'), ('VeteransHealth', 'NOUN'), ('thank', 'NOUN'), ('you', 'PRON'), ('.', '.'), ('#', '.'), ('#', '.'), ('⃝꙰⃝꙰⃝꙰⃝꙰⃝꙰⃝꙰⃝꙰⃝꙰⃝꙰⃝꙰⃝꙰⃝꙰⃝꙰⃝꙰⃝꙰⃝', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('anandiyermd', 'NOUN'), (':', '.'), ('This', 'DET'), ('is', 'VERB'), ('a', 'DET'), ('great', 'ADJ'), ('outreach', 'NOUN'), ('model', 'NOUN'), (':', '.'), ('senior', 'ADJ'), ('buddies', 'NOUN'), ('going', 'VERB'), ('door-to-door', 'ADJ'), ('in', 'ADP'), ('D.C.', 'NOUN'), ('to', 'PRT'), ('improve', 'VERB'), ('outreach', 'NOUN'), ('to', 'PRT'), ('older', 'ADJ'), ('adults', 'NOUN'), ('who', 'PRON'), ('may', 'VERB'), ('be', 'VERB'), ('a…', 'ADJ')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('SCNosalMD', 'NOUN'), (':', '.'), ('This', 'DET'), ('exactly👇🏼', 'NOUN'), ('!', '.'), ('#', '.'), ('peoplewhohavequestions', 'NOUN'), ('#', '.'), ('whathaveyourheard', 'ADV'), ('#', '.'), ('covidvaccine', 'ADJ'), ('#', '.'), ('ThisIsOurShot', 'NOUN'), ('#', '.'), ('BlackWhysMatter', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('#', '.'), ('COVID19', 'NOUN'), ('#', '.'), ('COVIDVaccine', 'NOUN'), ('Do', 'NOUN'), ('Not', 'ADV'), ('take', 'VERB'), ('someone', 'NOUN'), ('else', 'ADV'), ('’', 'NOUN'), ('s', 'NOUN'), ('vaccine', 'NOUN'), (',', '.'), ('Thou', 'NOUN'), ('Shalt', 'NOUN'), ('Not', 'ADV'), ('Steal', 'NOUN'), ('.', '.'), ('Do', 'NOUN'), ('not', 'ADV'), ('fly', 'VERB'), ('your', 'PRON'), ('extended', 'ADJ'), ('family', 'NOUN'), ('in…', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/1MPNhZg0B4', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('Love', 'NOUN'), (',', '.'), ('love', 'VERB'), ('@', 'NOUN'), ('MavericksMusic', 'NOUN'), ('and', 'CONJ'), ('their', 'PRON'), ('incredible', 'ADJ'), ('drummer', 'NOUN'), ('@', 'NOUN'), ('mavpaul59', 'NOUN'), ('used', 'VERB'), ('this', 'DET'), ('awesome', 'ADJ'), ('hashtag', 'NOUN'), ('#', '.'), ('vaccinesaresexy', 'ADJ'), ('Just…', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/JYw7RMqunP', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('DCKamrupMetro', 'NOUN'), (':', '.'), ('Shri', 'NOUN'), ('Biswajit', 'NOUN'), ('Pegu', 'NOUN'), (',', '.'), ('DC', 'NOUN'), ('Kamrup', 'NOUN'), ('Metro', 'NOUN'), ('along', 'ADP'), ('with', 'ADP'), ('other', 'ADJ'), ('Kamrup', 'NOUN'), ('Metro', 'NOUN'), ('District', 'NOUN'), ('Administration', 'NOUN'), ('Officers', 'NOUN'), ('takes', 'VERB'), ('1st', 'NUM'), ('dose', 'NOUN'), ('of', 'ADP'), ('#', '.'), ('Co…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('jacobthomas1960', 'NOUN'), (':', '.'), ('World', 'NOUN'), ("'s", 'PRT'), ('largest', 'ADJ'), ('vaccine', 'NOUN'), ('provider', 'NOUN'), ('.', '.'), ('#', '.'), ('CovidVaccine', 'NOUN'), ('#', '.'), ('IndiaFightsCorona', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/8J4jnOJ87w', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('@', 'ADJ'), ('silke4senate', 'NOUN'), ('@', 'NOUN'), ('abcdiagnosis', 'NOUN'), ('@', 'NOUN'), ('JJ_locked', 'NOUN'), ('@', 'NOUN'), ('AMJohnston1315', 'NOUN'), ('@', 'NOUN'), ('JulieMeryl09', 'NOUN'), ('@', 'NOUN'), ('fitwithjanice', 'NOUN'), ('@', 'NOUN'), ('fiestyivy', 'NOUN'), ('@', 'NOUN'), ('drawstickpeople…', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/BWbYYy0nOh', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('Got', 'NOUN'), ('ta', 'PRON'), ('Shot', 'NOUN'), ('#', '.'), ('covidvaccine', 'NOUN'), ('#', '.'), ('moderna', 'ADJ'), ('#', '.'), ('1stshot', 'NUM'), ('#', '.'), ('hamilton', 'NOUN'), ('#', '.'), ('youcandoit', 'ADV'), ('#', '.'), ('historicachievement', 'ADJ'), ('#', '.'), ('vaxxer', 'ADJ'), ('#', '.'), ('socialism…', 'ADJ'), ('https', 'NOUN'), (':', '.'), ('//t.co/1KdKM4FcnR', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('UCIrvineHealth', 'NOUN'), (':', '.'), ('Even', 'ADV'), ('if', 'ADP'), ('you', 'PRON'), ('had', 'VERB'), ('#', '.'), ('COVID19', 'NOUN'), (',', '.'), ('you', 'PRON'), ('should', 'VERB'), ('still', 'ADV'), ('get', 'VERB'), ('the', 'DET'), ('shots', 'NOUN'), (',', '.'), ('which', 'DET'), ('offer', 'VERB'), ('longer', 'ADJ'), ('immunity', 'NOUN'), ('.', '.'), ('However', 'ADV'), (',', '.'), ('you', 'PRON'), ('should', 'VERB'), ('NOT', 'VERB'), ('receive…', 'VERB')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('ochealth', 'NOUN'), (':', '.'), ('Sign-up', 'ADJ'), ('to', 'PRT'), ('receive', 'VERB'), ('our', 'PRON'), ('#', '.'), ('OCCOVID19', 'NOUN'), ('Vaccine', 'NOUN'), ('Facts', 'NOUN'), ('newsletter', 'NOUN'), ('and', 'CONJ'), ('receive', 'VERB'), ('a', 'DET'), ('weekly', 'ADJ'), ('digest', 'NOUN'), ('of', 'ADP'), ('information', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('news', 'NOUN'), ('you', 'PRON'), ('need', 'VERB'), ('t…', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('Death', 'NOUN'), (',', '.'), ('Through', 'ADP'), ('a', 'DET'), ('Nurse', 'NOUN'), ('’', 'NOUN'), ('s', 'VERB'), ('Eyes', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/Sh08QVcGcu', 'ADJ'), ('#', '.'), ('empathy', 'ADJ'), ('#', '.'), ('nurses', 'NOUN'), ('#', '.'), ('COVID19', 'NOUN'), ('#', '.'), ('StopTheSpread', 'NOUN'), ('#', '.'), ('COVIDVaccine', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('RT', 'NOUN'), ('@', 'NOUN'), ('jacobthomas1960', 'NOUN'), (':', '.'), ('World', 'NOUN'), ("'s", 'PRT'), ('largest', 'ADJ'), ('vaccine', 'NOUN'), ('provider', 'NOUN'), ('.', '.'), ('#', '.'), ('CovidVaccine', 'NOUN'), ('#', '.'), ('IndiaFightsCorona', 'NOUN'), ('https', 'NOUN'), (':', '.'), ('//t.co/8J4jnOJ87w', 'NOUN')]
# <FreqDist with 8 samples and 33 outcomes>
# [('@', 'ADJ'), ('Jessicam6946', 'NOUN'), ('Of', 'ADP'), ('course', 'NOUN'), ('!', '.'), ('!', '.'), ('#', '.'), ('COVIDVaccine', 'NOUN'), ('#', '.'), ('GetVaccinated', 'VERB')]
# <FreqDist with 8 samples and 33 outcomes>
# ...
# (NP (NNP RT) (NNP @nilikm) (: :))
# (NP (NP (NNP RT) (CD @WajidRizvi1)) (: :) (WHADVP (RB Not) (WHADVP (WRB how))) (S (VP (VBD envisioned) (NP (NP (NP (PRP$ my) (JJ 1st) (NN trip)) (PP (IN to) (NP (NNP @GlobeLifeField)))) (S (VP (VBG Getting) (S (NP (PRP$ my) (NNP Grandmother)) (VP (VBN vaccinated) (PP (IN for) (NP (NNP Covid) (CD 19)))))))))) (. .) (_SP  ))
# (NP (NP (NNP RT) (CD @jacobthomas1960)) (: :) (NP (NP (NNP World) (POS 's)) (JJS largest) (NN vaccine) (NN provider)) (. .) (_SP
# ))
# (NP (NFP #) (NNP CovidVaccine) (NNP https://t.co/VqBV4IRNEo))
# (X (DT Y’ALL))
# (NP (NNP RT) (NNP @Taleeb) (: :))
# (NP (NNP RT) (NNP @GovCanHealth) (: :))
# (NP (NNP RT) (NNP @ZeldinRecord))
# (NP (NNP RT) (CD @R_Good_Fellow_1) (: :))
# (NP (NP (QP (RB Only) (CD 333k)) (NNS people)) (ADVP (RB ahead) (PP (IN of) (NP (PRP me)))) (PP (IN in) (NP (NP (NN line)) (PP (_SP  ) (PP (IN for) (NP (`` #) (NNP COVIDVaccine) (NNP https://t.co/cohLEGW8vS)))))))
# (NP (NP (NNP RT) (NNP @DVBergen)) (: :) (S (NP (NP (JJ Municipal) (NNS officials)) (PP (IN in) (NP (DT this) (NML (NNP New) (NNP Jersey)) (NN city)))) (VP (VBP are) (VP (VBG getting) (PP (IN behind) (NP (DT the) (NN wheel))) (S (VP (TO to) (VP (VB bring) (NP (NNS residents)) (PP (IN in) (NP (NP (NN need)) (PP (IN of) (NP (NP (NNS rides)) (PP (IN to) (NP (PRP$ their) (CD COVID-1))))))))))))) (: …))
# (NP (NNP RT) (CD @USMC_O311))
# (NP (NNP RT) (NNP @PrincessZeeGirl) (: :))
# (ADJP (VBN Thrilled) (S (VP (TO to) (VP (VB see) (S (NP (NNP FDA)) (VP (VB recommend) (NP (NNP J&amp;J) (HYPH #) (NNP COVIDVaccine)) (VP (RB co) (HYPH -) (VBN developed) (PP (IN by) (NP (NP (JJ amazing) (NNS colleagues)) (NP (NNP @k_stephensonMD)))))))))))
# (S (NP (PRP I)) (VP (VBP miss) (S (VP (VBG being) (VP (VBN invited) (PP (IN for) (NP (DT a) (NNS girls) (NN night))))))) (. .))
# (NP (NN Vaccine) (_SP
# ) (NN #) (NNP COVIDVaccine) (NNP https://t.co/CynMKgIoQa))
# (NP (NP (NNP RT) (CD @jacobthomas1960)) (: :) (NP (NP (NNP World) (POS 's)) (JJS largest) (NN vaccine) (NN provider)) (. .) (_SP
# ))
# (NP (NNP RT) (NNP @Shakesnews) (HYPH _) (: :) (NP (NP (NNS Vaccinations)) (PP (IN at) (NP (NP (NNP Oakland) (POS ’s)) (NNP Coliseum)))) (. .))
# (S (CC And) (NP (PRP you)) (VP (VBP think) (SBAR (S (NP (NNS people)) (VP (MD gon) (VP (TO na) (VP (VB take) (NP (DT this)) (PP (IN from) (S (VP (VBG fucking) (NP (NNP India))))))))))) (. ?))
# (NP (NNP RT) (NNP @WRES_team) (: :))
# (S (VP (VBG Dissing) (NP (NNP Dallas))) (. ?))
# (NP (NP (NNP RT) (NNP @SteveAdubato)) (: :) (NP (NP (`` #) (NN ThisWknd)) (IN on) (`` #) (NNP ThinkTankSA) (NNP @ShereefElnahal) (CC &) (NN amp) (: ;) (NP (NNP @DrChrisMD) (NNP @UnivHospNewark)) (: ;) (NP (NNP John) (NNP Harmon) (NNP @AACCNJ)) (: ;) (CC and) (NP (NNP @CarlosMedinaEsq) (NNP @SHCCNJ))) (: …))
# (NP (NP (QP (RB Only) (CD 333k)) (NNS people)) (ADVP (RB ahead) (PP (IN of) (NP (PRP me)))) (PP (IN in) (NP (NP (NN line)) (PP (_SP  ) (PP (IN for) (NP (NP (`` #) (NNP COVIDVaccine)) (NP (NNP https://t.co/mLFbOnFFCk))))))))
# (NP (NP (NNP RT) (NNP @USArmy)) (: :) (NP (NP (NNS Soldiers)) (PP (IN for) (NP (NNP Life)))))
# (S (INTJ (RB Ok)) (RB so) (NP (DT the) (`` #) (NNP COVIDVaccine)) (VP (VBZ is) (NP (JJ big) (NN government)) (SBAR (IN as) (SINV (VP (VBZ is)) (NP (DT the) (ADJP (ADJP (NN roll) (RP out)) (CC and) (ADJP (JJ free))) (NNS shots))))) (. .))
# (NP (NNP RT) (NNP @GovCanHealth) (: :))
# (NP (NNP RT) (NNP @GovCanHealth) (: :))
# (NP (NNP RT) (NNP @thetonymichaels) (: :))
# (NP (NNP RT) (NNP @PrincessZeeGirl) (: :))
# (NP (NP (NNP RT) (NNP @BSBreastCancer)) (: :) (NN @silke4senate) (NN @abcdiagnosis) (. @JJ_locked) (CD @AMJohnston1315))
# (NP (NP (NNP RT)) (VP (VBZ @kentcrexreacts)) (: :))
# (NP (NNP RT) (NNP @GovCanHealth) (: :))
# (NP (NNP RT) (NNP @IdaMHolguin))
# (NP (NNP RT) (NNP @PSPC_SPAC) (: :))
# (NP (DT This) (. !))
# (NP (NNP RT) (NNP @PIBShimla) (: :) (NP (`` #) (NP (NNP LargestVaccineDrive))) (_SP
#
# ))
# (NP (NNP RT) (NNP @GovCanHealth) (: :))
# (NP (NNP RT) (NNP @PIBShimla) (: :) (NP (`` #) (NP (NNP LargestVaccineDrive))) (_SP
#
# ))
# (NP (NP (NNP RT) (NNP @DrShaneRRR)) (: :) (S (NP (PRP I)) (VP (VBP want) (S (VP (TO to) (VP (VB see) (NP (DT a) (NML (`` #) (NNP COVIDVaccine)) (NN counter)) (PP (IN from) (NP (NNP @abcnews))) (PP (IN for) (NP (NNP Australia)))))))) (. .) (_SP
# ))
# (NP (NNP RT) (NNP @MarilynHeineMD) (: :))
# (X (NP (NNP RT) (NN @gamhcarercentre)) (: :) (S (NP (`` #) (NNP Glasgowcarers) (NP (DT the) (`` #) (NNP CovidVaccine))) (VP (VBZ is) (ADVP (RB currently)) (VP (VBG being) (VP (VBN rolled) (PRT (RP out)))))))
# (NP (NNP RT) (NNP @welosthim) (: :))
# (PP (LS अरे) (FW भिखारिन) (, ,) (FW भीख))
# (NP (NNP @JerrySoucyRN))
# (ADJP (ADJP (RB So) (JJ happy) (PP (IN for) (NP (PRP$ my) (NNS hubs)))) (. !))
# (NP (NP (DT A) (JJ helluva) (NN way)) (SBAR (S (VP (TO to) (VP (VB end) (NP (NN week)))))) (. !))
# (S (NP (NNP @ScottMorrisonMp)) (VP (VBZ advises) (SBAR (S (NP (PRP we)) (VP (MD should) (VB expect) (S (NP (EX there)) (VP (TO to) (VP (VB be) (NP (NN teething) (NNS problems)))))))) (SBAR (IN as) (S (NP (DT this)) (VP (VBZ is) (NP (JJ early) (NNS days)) (PP (IN in) (NP (DT the) (`` #) (NNP COVIDVaccine))))))) (: …) (NP (CD https://t.co/aJKS4cWt49)))
# (NP (NP (NNP RT) (NNP @prodefkohima)) (: :) (S (SBAR (IN While) (S (NP (DT the) (`` #) (NNP CovidVaccine)) (VP (VBZ is) (ADVP (RB NOW)) (ADJP (JJ available))))) (NP (NP (PRP it))) (VP (VBZ is) (ADJP (JJ critical)) (SBAR (IN that) (S (NP (NP (DT all)) (PP (IN of) (NP (PRP us)))) (VP (VB continue) (S (VP (TO to) (VP (VB follow) (NP (PDT all) (DT the) (`` #) (NNP COVID) (JJ Appropriate) (NNP Beha)))))))))) (: …))
# (S (IN So) (NP (NP (DT the) (JJ amazing) (NN team)) (PP (IN at) (NP (NNP https://t.co/zFvTfvagja)))) (VP (VBD managed) (S (VP (TO to) (VP (VB get) (NP (PRP$ my) (NN father)) (NP (NP (DT a) (NN vaccine) (NN appointment)) (PP (IN for) (NP (NN tomorrow)))))))) (. .))
# (FRAG (ADVP (RB Sure)) (, ,) (SBAR (WHADVP (WRB how)) (S (NP (NP (PRP it))) (VP (VBZ feels) (S (VP (TO to) (VP (VB be) (ADJP (JJ rich)))))))))
# (NP (NP (NNP RT) (CD @jacobthomas1960)) (: :) (NP (NP (NNP World) (POS 's)) (JJS largest) (NN vaccine) (NN provider)) (. .) (_SP
# ))
# (NP (`` ") (NP (NP (NP (NNP Transatlantic) (NNP Trade)) (: |) (NP (NNP US) (CC and) (NNP Europe))) (: –) (NP (NP (NNP Week)) (PP (IN of) (NP (NNP February) (CD 22) (, ,) (CD 2021))))) ('' ") (NP (NNP https://t.co/2x8AILCkyl) (SYM #) (NNP UK)))
# (NP (NNP RT) (NNP @GovCanHealth) (: :))
# (NP (NNP RT) (NNP @nilikm) (: :))
# (S (SBAR (IN If) (S (NP (PRP you)) (VP (VBP get) (NP (PRP$ your) (`` #) (NNP COVIDVaccine))))) (NP (PRP you)) (VP (VP (MD will) (VP (VB be) (VP (VBN microchipped)))) (: ..) (NP (PRP THEY)) (VP (MD will) (VP (VB be) (VP (VBG following) (NP (PRP YOU)))))) (. !) (. !))
# (NP (NNPS @CBCAlerts) (NNP Cool) (. .))
# (NP (NN Poll) (: :) (_SP
#
# ))
# (NP (NP (NNP @TNChapterACS) (NNP @UTKnoxSurgery) (NNP @utmedicalcenter)) (NP (JJ Great) (NN job)) (NP (NP (NNP Dr.) (NNP Gray)) (CC and) (NP (NN team))) (. !))
# (NP (NP (NNP RT) (CD @jacobthomas1960)) (: :) (NP (NP (NNP World) (POS 's)) (JJS largest) (NN vaccine) (NN provider)) (. .) (_SP
# ))
# (NP (NNP RT) (NNP @DrNinaRadcliff) (: :))
# (INTJ (UH Yes) (. !))
# (S (NP (PRP I)) (VP (VP (VBP ask) (NP (PRP myself)) (SBAR (WHNP (WHNP (WP who)) (PP (IN at) (NP (DT the) (NNP @CDCgov)))) (S (VP (VBZ does) (RB n't) (VP (VB put) (NP (HYPH #) (NN cancer) (CC and) (JJ vulnerable)) (PP (IN in) (NP (DT the) (JJ same) (NN sentence))) (SBAR (WHADVP (WRB when)) (S (VP (VBG speaking) (PP (IN of) (NP (DT the) (`` #) (NNP COVID))))))))))) (: …) (NP (NNP https://t.co/4gIpgv4hwo))))
# (NP (NNP RT) (NNP @MarilynHeineMD) (: :))
# (FRAG (ADJP (RB Well) (VBN done)) (CC and) (VP (VB thank) (NP (PRP you)) (NP (NNP @MarisePayne))) (. .))
# (S (NP (NNP RT) (NNP @Refugees)) (: :) (NP (NP (NNP @WHO) (NNP @DrMikeRyan) (. @FilippoGrandi)) (S (VP (VBG Including) (NP (NNS refugees)) (PP (IN in) (NP (JJ national) ($ #) (NNP COVIDvaccine) (NNS plans)))))) (VP (VBZ is) (ADJP (JJ key) (PP (IN to) (S (VP (VBG ensuring) (SBAR (S (NP (PRP we)) (VP (VBP protect) (NP (ADJP (RB as) (JJ many)) (NN peop)))))))))) (: …))
# (NP (NNP RT))
# (NP (NNP RT) (NNP @MarilynHeineMD) (: :))
# (NP (JJ New) (`` #) (NNP WeekinReview) (SYM #) (NP (NNP Biden)) (-LRB- #) (CD COVID19) (SYM #) (NP (NNP COVIDVaccine)) (SYM #) (NP (NNP FederalReserve)) (HYPH #) (NNP WallStreet) (SYM #) (NN bondmarket) (SYM #) (NNP Trump) (SYM #) (CD CPAC2021))
# (NP (NFP #) (NP (NNP CovidVaccine)) (SYM #) (NNP PharmacyoftheWorld) (`` #) (NP (NNP IndiaforHumanity)) (SYM #) (NP (NNP AffordableVaccines4All)) (PP (_SP
# ) (NP (NNP @MEAIndia))))
# (S (-RRB- .⁦@AmerMedicalAssn⁩) (VP (VP (VBZ urges) (NP (NNP @WhiteHouse)) (S (VP (TO to) (VP (VB include) (NP (NN physician) (NNS offices)) (PP (IN in) (NP (`` #) (NNP CovidVaccine) (NML (NN distribution) (CC and) (NN delivery)) (NNS plans))))))) (: …) (NP (NNP https://t.co/OVRHnkuoks))))
# (NP (NNP @GoHealio) (NNP @TheGrahamCenter) (NNP @PCPCC) (NNP @DarilynMoyer) (NNPS @ACPinternists) (NNP @DrAngelicaDrPH))
# (NP (NNP RT) (NNP @GovCanHealth) (: :))
# (NP (NNP RT) (NNP @khansh) (: :))
# (S (NP (NP (QP (RB Only) (CD 11)) (NN %)) (PP (IN of) (NP (NP (JJ Medical) (NNS professionals)) (PP (IN in) (NP (NNP India)))))) (VP (VBD agreed) (S (VP (TO to) (VP (VB take) (NP (NP (DT the) (NNP Covaxin) (NN shot)) (-LRB- -LRB-) (VP (VBN manufactured) (PP (IN by) (NP (NNP Bharat) (NNP Biotech)))) (-RRB- -RRB-)))))) (. .))
# (NP (LS @CNY315) (: _) (NNP @CEJRyanMcMahon) (NNP @ClaudiaTenney) (NNP @RepJohnKatko) (NNP @YoungKimCA) (. @aslavitt46) (NNP @JoeBiden) (. @WHCOS) (NP (NP (NN Today) (POS 's)) (: …) (NP (NNP https://t.co/MRWBx4DUtZ))))
# (ADJP (ADJP (RB So) (JJ excited)) (. !) (. !) (. !))
# (NP (NFP #) (NNP LargestVaccineDrive) (_SP
#
# ))
# (NP (NFP #) (NNP COVIDVaccine) (NNP https://t.co/RSypTHWI8O))
# (NP (NP (NNP RT) (NN @cna006)) (: :) (NP (FW @jpquinteros) (NNP @marklewismd)) (: 😂) (NP (NP (NNS thanks)) (PP (IN for) (NP (DT the) (NN laugh)))) (. !))
# (S (VP (VBG Feeling) (ADJP (RB down))) (. ?))
# (NP (NFP #) (NNP LargestVaccineDrive) (_SP
#
# ))
# (NP (NP (NFP #) (NNP COVIDVaccine)) (NP (NN tomorrow)) (. .))
# (NP (NP (NNP RT) (NNP @anandiyermd)) (: :) (S (NP (DT This)) (VP (VBZ is) (NP (NP (DT a) (JJ great) (NN outreach) (NN model)) (: :) (NP (NP (JJ senior) (NNS buddies)) (VP (VBG going) (NP (NML (NN door)) (HYPH -) (PP (IN to) (HYPH -) (NP (NN door)))) (PP (IN in) (NP (NNP D.C.))) (S (VP (TO to) (VP (VB improve) (NP (NP (NN outreach)) (PP (IN to) (NP (NP (JJR older) (NNS adults)) (SBAR (WHNP (WP who)) (S (VP (MD may) (VP (VB be) (NP (DT a))))))))))))))))) (: …))
# (NP (NNP RT))
# (S (S (NP (-LRB- #) (CD COVID19) (SYM #) (NNP COVIDVaccine)) (VP (VBP Do) (RB Not) (VP (VB take) (NP (NP (NN someone) (JJ else) (POS ’s)) (NN vaccine))))) (, ,) (S (NP (NNP Thou)) (VP (MD Shalt) (RB Not) (VP (VB Steal)))) (. .))
# (S (NP (NP (NN Love) (, ,) (NN love) (NNP @MavericksMusic)) (CC and) (NP (NP (PRP$ their) (JJ incredible) (NN drummer)) (NP (CD @mavpaul59)))) (VP (VBD used) (NP (NP (DT this) (JJ awesome) (NN hashtag)) (PP (`` #) (NP (NN vaccinesaresexy))))))
# (NP (NNP RT) (NNP @DCKamrupMetro) (: :))
# (NP (NP (NNP RT) (CD @jacobthomas1960)) (: :) (NP (NP (NNP World) (POS 's)) (JJS largest) (NN vaccine) (NN provider)) (. .) (_SP
# ))
# (NP (NN @silke4senate) (NN @abcdiagnosis) (. @JJ_locked) (CD @AMJohnston1315) (-RRB- @JulieMeryl09))
# (NP (NP (NNP Got) (NNP ta) (NNP Shot)) (_SP
#
# ) (`` #) (NN covidvaccine) (HYPH #) (NN moderna) (CD #) (NN 1stshot) (`` #) (NN hamilton) (HYPH #) (NN youcandoit) (HYPH #) (NN historicachievement) (`` #) (NN vaxxer) (HYPH #) (NN socialism) (: …) (NP (NNP https://t.co/1KdKM4FcnR)))
# (NP (NNP RT) (NNP @UCIrvineHealth) (: :))
# (NP (NP (NNP RT) (NNP @ochealth)) (: :) (S (VP (VP (VB Sign) (PRT (HYPH -) (PRT (RP up))) (S (VP (TO to) (VP (VB receive) (NP (PRP$ our) (NML ($ #) (NNP OCCOVID19)) (NML (NNP Vaccine) (NNPS Facts)) (NN newsletter)))))) (CC and) (VP (VB receive) (NP (NP (DT a) (JJ weekly) (NN digest)) (PP (IN of) (NP (NP (NN information)) (CC and) (NP (NP (DT the) (NN news)) (SBAR (S (NP (PRP you)) (VP (VBP need) (RB t))))))))))) (: …))
# (NP (NP (NN Death)) (, ,) (PP (IN Through) (NP (NP (DT a) (NNP Nurse) (POS ’s)) (NNPS Eyes))) (. https://t.co/Sh08QVcGcu))
# (NP (NP (NNP RT) (CD @jacobthomas1960)) (: :) (NP (NP (NNP World) (POS 's)) (JJS largest) (NN vaccine) (NN provider)) (. .) (_SP
# ))
# (X (NP (LS @Jessicam6946)) (ADVP (RB Of) (RB course)) (. !) (. !) (NP (`` #) (NP (NN COVIDVaccine)) (`` #) (VP (VBN GetVaccinated))))
# GPE Ontario
# ORG Health Canada
# ORG AstraZeneca
# ORG the Serum Institute of India
# MONEY #teacherbestie @WestsidehsTeach
# GPE Ontario
# ORDINAL 1st
# FAC Covid 19
# PERSON CovidVaccine https://t.co/VqBV4IRNEo
# ORG COLD AS
# MONEY #COVIDVaccine #
# CARDINAL 6.5
# DATE the next 35 days
# MONEY #WearAMask #Wa
# ORG Health Canada
# ORG AstraZeneca
# ORG the Serum Institute of India
# DATE the 23 year old
# GPE Moderna
# CARDINAL 15
# CARDINAL Only 333k
# GPE New Jersey
# CARDINAL 8 million
# DATE the age of 65
# CARDINAL 1 million
# CARDINAL 50
# GPE Israel
# NORP Palestinians
# CARDINAL 👇
# ORG FDA
# TIME a girls night
# TIME the night
# PERSON COVIDVaccine
# GPE Oakland
# GPE India
# NORP non-English
# GPE London
# GPE Dallas
# PERSON Clay Jenkins
# NORP North Texans
# PERSON ThisWknd
# ORG ThinkTankSA @ShereefElnahal &amp
# PERSON John Harmon @AACCNJ
# ORG @SHCCNJ
# CARDINAL Only 333k
# ORG CovidVaccine
# PERSON Alexis Ruth
# ORG @MDNG
# ORG Health Canada
# ORG AstraZeneca
# ORG the Serum Institute of India
# ORG Health Canada
# ORG AstraZeneca
# ORG the Serum Institute of India
# ORG Talk 🎤 Booger
# GPE Israel
# NORP Palestinians
# CARDINAL 👇
# DATE 2nd
# MONEY #vaccinated #COVID19Vaccine #
# PERSON Moderna
# ORG Health Canada
# ORG AstraZeneca
# ORG the Serum Institute of India
# ORDINAL first
# ORDINAL second
# GPE Canada
# CARDINAL 2 million
# ORG AstraZeneca
# ORDINAL first
# CARDINAL 500,000
# ORG Health Canada
# ORG AstraZeneca
# ORG the Serum Institute of India
# MONEY #COVIDVaccine counter
# ORG @abcnews
# GPE Australia
# ORG @WhiteHouse
# PERSON CovidVaccine
# PERSON Glasgowcarers
# PRODUCT CovidVaccine
# ORG Carers Centre
# PERSON 😆😆
# DATE 14 days
# DATE 2510
# CARDINAL 2
# ORDINAL Second
# DATE end week
# PERSON 👏
# CARDINAL One
# PERSON 💥
# PERSON 🙏🏼…
# DATE early days
# ORG CovidVaccine
# ORG NOW
# DATE tomorrow
# GPE US
# LOC Europe
# DATE Week of February 22, 2021
# MONEY #UK
# MONEY #COVIDVaccine @SPB_Global
# ORG Health Canada
# ORG AstraZeneca
# ORG the Serum Institute of India
# GPE Ontario
# PERSON COVIDVaccine
# ORG THEY
# DATE decades
# PERSON Gray
# PERSON Proud
# EVENT @utmedicalcenter
# NORP Americans
# CARDINAL #
# CARDINAL #
# ORG @CDCgov
# ORG @WhiteHouse
# PERSON CovidVaccine
# ORG @MarisePayne
# PERSON COVIDvaccine
# ORG @tedcruz
# ORG @WhiteHouse
# PERSON CovidVaccine
# MONEY #COVIDVaccine #
# MONEY #bondmarket #Trump
# MONEY #CPAC2021
# MONEY Iran
# ORG CovidVaccine
# ORG PharmacyoftheWorld
# GPE @MEAIndia
# ORG @WhiteHouse
# PERSON CovidVaccine
# ORG @TheGrahamCenter @PCPCC
# ORG @lloydmichener
# ORG Health Canada
# ORG AstraZeneca
# ORG the Serum Institute of India
# PERCENT Only 11%
# GPE India
# GPE Covaxin
# PERSON Bharat Biotech
# PERCENT Only 11%
# GPE India
# GPE Covaxin
# PERSON Bharat Biotech
# ORG @aslavitt46
# ORG @WHCOS
# DATE Today
# ORDINAL first
# PERSON Fauci Ouchie
# DATE next week
# PERSON FauciOuchie
# MONEY about #COVIDVaccine
# PERSON Hu
# DATE weekend
# ORG #TeamCVS &amp
# PERSON COVIDVaccine
# DATE tomorrow
# FAC Christmas Eve
# MONEY #
# GPE D.C.
# MONEY #peoplewhohavequestions #
# MONEY #covidvaccine #
# PERSON Thou Shalt Not Steal
# ORG @MavericksMusic
# ORG @mavpaul59
# PERSON Shri Biswajit Pegu
# PERSON Kamrup Metro
# ORG Kamrup Metro District Administration Officers
# DATE 1st
# MONEY Co
# ORG @JJ_locked
# ORG @fitwithjanice @fiestyivy @drawstickpeople
# CARDINAL https://t.co/BWbYYy0nOh
# ORG Shot
# MONEY #covidvaccine #moderna
# MONEY #vaxxer #
# DATE weekly
# MONEY #COVID19
# MONEY #COVIDVaccine #
# FreqDist({'CARDINAL': 16,
#           'DATE': 17,
#           'EVENT': 1,
#           'FAC': 2,
#           'GPE': 20,
#           'LOC': 1,
#           'MONEY': 20,
#           'NORP': 5,
#           'ORDINAL': 6,
#           'ORG': 57,
#           'PERCENT': 2,
#           'PERSON': 29,
#           'PRODUCT': 1,
#           'TIME': 2})

# %% [markdown]
# **Write your explanations of the constituency parsing tree and dependency parsing tree here (Question 3-2):**

# %%
'''
Write your explanations of the constituency parsing tree and dependency parsing tree here
'''
#Constituency parsing tree
'''
>> Constituency parsing is analysing the sub phrases by breaking the sentence. These sub phrases are also known as constituents. The constituents are categorized 
into different categories of grammar like Noun and Verb phrase.

>> Constituency parsing aims to extract a constituency-based parse tree from a sentence that 
represents its syntactic structure according to a phrase structure grammar.
For example, the phrases "a cat", "a dog", "a computer " are all Noun phrases, where as "eat a pizza" " go to school" are all verb phrases'''

#Dependency parsing tree
'''Dependency parsing is opposite to constituency parsing, dependency parsing doesnot make use of constituents or sub-phrases.
Depndency parse tree first divides all words in a sentence and furthur establishes the reationship between the words for the better syntactic understanding.
Dependency parsing considers each word as a node. In this parsing each word is connected based on their relationships. 
'''


'''
# Out:
# '\nWrite your explanations of the constituency parsing tree and dependency parsing tree here\n\n\n\n'
